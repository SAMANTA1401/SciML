# %%
import Pkg

# %%
Pkg.add("OrdinaryDiffEq")
# Out:
#     Updating registry at `C:\Users\lenovo\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed FastGaussQuadrature ───────────────── v1.0.2
#    Installed OrdinaryDiffEqRosenbrock ──────────── v1.11.0
#    Installed OrdinaryDiffEqRKN ─────────────────── v1.1.0
#    Installed OrdinaryDiffEqSDIRK ───────────────── v1.3.0
#    Installed TimerOutputs ──────────────────────── v0.5.29
#    Installed Accessors ─────────────────────────── v0.1.42
#    Installed OrdinaryDiffEqStabilizedRK ────────── v1.1.0
#    Installed OrdinaryDiffEqPRK ─────────────────── v1.1.0
#    Installed Polyester ─────────────────────────── v0.7.18
#    Installed NonlinearSolve ────────────────────── v4.9.0
#    Installed SciMLJacobianOperators ────────────── v0.1.6
#    Installed EnumX ─────────────────────────────── v1.0.5
#    Installed FunctionWrappers ──────────────────── v1.1.3
#    Installed MaybeInplace ──────────────────────── v0.1.4
#    Installed StaticArrays ──────────────────────── v1.9.13
#    Installed OrdinaryDiffEqAdamsBashforthMoulton ─ v1.2.0
#    Installed RecursiveArrayTools ───────────────── v3.34.1
#    Installed OrdinaryDiffEqCore ────────────────── v1.26.2
#    Installed Statistics ────────────────────────── v1.11.1
#    Installed IntelOpenMP_jll ───────────────────── v2025.0.4+0
#    Installed MuladdMacro ───────────────────────── v0.2.4
#    Installed FiniteDiff ────────────────────────── v2.27.0
#    Installed SIMDTypes ─────────────────────────── v0.1.0
#    Installed Static ────────────────────────────── v1.2.0
#    Installed OrdinaryDiffEqSSPRK ───────────────── v1.3.0
#    Installed IrrationalConstants ───────────────── v0.2.4
#    Installed OrdinaryDiffEqVerner ──────────────── v1.2.0
#    Installed FastPower ─────────────────────────── v1.1.3
#    Installed DiffEqBase ────────────────────────── v6.177.2
#    Installed OrdinaryDiffEqFIRK ────────────────── v1.12.0
#    Installed NonlinearSolveQuasiNewton ─────────── v1.6.0
#    Installed SimpleUnPack ──────────────────────── v1.1.0
#    Installed CpuId ─────────────────────────────── v0.3.1
#    Installed SciMLBase ─────────────────────────── v2.102.1
#    Installed OrdinaryDiffEqNonlinearSolve ──────── v1.10.0
#    Installed BracketingNonlinearSolve ──────────── v1.3.0
#    Installed SimpleNonlinearSolve ──────────────── v2.5.0
#    Installed ADTypes ───────────────────────────── v1.15.0
#    Installed SpecialFunctions ──────────────────── v2.5.1
#    Installed LineSearch ────────────────────────── v0.1.4
#    Installed LinearSolve ───────────────────────── v3.18.2
#    Installed OrdinaryDiffEq ────────────────────── v6.98.0
#    Installed NonlinearSolveSpectralMethods ─────── v1.2.0
#    Installed IfElse ────────────────────────────── v0.1.1
#    Installed NaNMath ───────────────────────────── v1.1.3
#    Installed ManualMemory ──────────────────────── v0.1.8
#    Installed StaticArraysCore ──────────────────── v1.4.3
#    Installed ThreadingUtilities ────────────────── v0.5.5
#    Installed SparseMatrixColorings ─────────────── v0.4.21
#    Installed NLSolversBase ─────────────────────── v7.10.0
#    Installed DataStructures ────────────────────── v0.18.22
#    Installed ExprTools ─────────────────────────── v0.1.10
#    Installed LazyArrays ────────────────────────── v2.6.1
#    Installed CommonWorldInvalidations ──────────── v1.0.0
#    Installed Compat ────────────────────────────── v4.17.0
#    Installed CommonSubexpressions ──────────────── v0.3.1
#    Installed StaticArrayInterface ──────────────── v1.8.0
#    Installed oneTBB_jll ────────────────────────── v2022.0.0+0
#    Installed OrdinaryDiffEqLinear ──────────────── v1.3.0
#    Installed ArrayLayouts ──────────────────────── v1.11.1
#    Installed BitTwiddlingConvenienceFunctions ──── v0.1.6
#    Installed SciMLStructures ───────────────────── v1.7.0
#    Installed DiffRules ─────────────────────────── v1.15.1
#    Installed FunctionWrappersWrappers ──────────── v0.1.3
#    Installed GenericSchur ──────────────────────── v0.5.5
#    Installed TableTraits ───────────────────────── v1.0.1
#    Installed OrdinaryDiffEqExplicitRK ──────────── v1.1.0
#    Installed OrdinaryDiffEqPDIRK ───────────────── v1.3.1
#    Installed OrdinaryDiffEqQPRK ────────────────── v1.1.0
#    Installed LayoutPointers ────────────────────── v0.1.17
#    Installed DiffResults ───────────────────────── v1.1.0
#    Installed OrdinaryDiffEqFunctionMap ─────────── v1.1.1
#    Installed PrettyTables ──────────────────────── v2.4.0
#    Installed SciMLOperators ────────────────────── v1.3.1
#    Installed NonlinearSolveBase ────────────────── v1.12.0
#    Installed Setfield ──────────────────────────── v1.1.2
#    Installed MKL_jll ───────────────────────────── v2025.0.1+1
#    Installed OrdinaryDiffEqLowOrderRK ──────────── v1.2.0
#    Installed EnzymeCore ────────────────────────── v0.8.12
#    Installed NonlinearSolveFirstOrder ──────────── v1.5.0
#    Installed ConstructionBase ──────────────────── v1.6.0
#    Installed ExproniconLite ────────────────────── v0.10.14
#    Installed OrderedCollections ────────────────── v1.8.1
#    Installed PolyesterWeave ────────────────────── v0.2.2
#    Installed DataValueInterfaces ───────────────── v1.0.0
#    Installed OrdinaryDiffEqExponentialRK ───────── v1.4.0
#    Installed FastClosures ──────────────────────── v0.3.2
#    Installed LineSearches ──────────────────────── v7.4.0
#    Installed ArrayInterface ────────────────────── v7.19.0
#    Installed ChainRulesCore ────────────────────── v1.25.2
#    Installed Reexport ──────────────────────────── v1.2.2
#    Installed OrdinaryDiffEqTsit5 ───────────────── v1.1.0
#    Installed CloseOpenIntervals ────────────────── v0.1.13
#    Installed LogExpFunctions ───────────────────── v0.3.29
#    Installed OrdinaryDiffEqLowStorageRK ────────── v1.3.0
#    Installed OrdinaryDiffEqExtrapolation ───────── v1.5.0
#    Installed PreallocationTools ────────────────── v0.4.28
#    Installed CompositionsBase ──────────────────── v0.1.2
#    Installed MacroTools ────────────────────────── v0.5.16
#    Installed OpenSpecFun_jll ───────────────────── v0.5.6+0
#    Installed OrdinaryDiffEqStabilizedIRK ───────── v1.3.0
#    Installed UnPack ────────────────────────────── v1.0.2
#    Installed InverseFunctions ──────────────────── v0.1.17
#    Installed CommonSolve ───────────────────────── v0.2.4
#    Installed Krylov ────────────────────────────── v0.10.1
#    Installed DocStringExtensions ───────────────── v0.9.5
#    Installed ExponentialUtilities ──────────────── v1.27.0
#    Installed GPUArraysCore ─────────────────────── v0.2.0
#    Installed Crayons ───────────────────────────── v4.1.1
#    Installed Adapt ─────────────────────────────── v4.3.0
#    Installed DifferentiationInterface ──────────── v0.7.2
#    Installed OrdinaryDiffEqBDF ─────────────────── v1.6.0
#    Installed RuntimeGeneratedFunctions ─────────── v0.5.15
#    Installed StrideArraysCore ──────────────────── v0.5.7
#    Installed OrdinaryDiffEqDifferentiation ─────── v1.10.0
#    Installed OrdinaryDiffEqHighOrderRK ─────────── v1.1.0
#    Installed OrdinaryDiffEqFeagin ──────────────── v1.1.0
#    Installed Jieko ─────────────────────────────── v0.2.1
#    Installed CPUSummary ────────────────────────── v0.2.6
#    Installed Tables ────────────────────────────── v1.12.1
#    Installed Moshi ─────────────────────────────── v0.3.7
#    Installed DataAPI ───────────────────────────── v1.16.0
#    Installed TruncatedStacktraces ──────────────── v1.4.0
#    Installed ConcreteStructs ───────────────────── v0.2.3
#    Installed RecipesBase ───────────────────────── v1.3.4
#    Installed IteratorInterfaceExtensions ───────── v1.0.0
#    Installed LaTeXStrings ──────────────────────── v1.4.0
#    Installed SymbolicIndexingInterface ─────────── v0.3.41
#    Installed FillArrays ────────────────────────── v1.13.0
#    Installed ForwardDiff ───────────────────────── v1.0.1
#    Installed OrdinaryDiffEqSymplecticRK ────────── v1.3.0
#    Installed OrdinaryDiffEqDefault ─────────────── v1.5.0
#    Installed Requires ──────────────────────────── v1.3.1
#    Installed StringManipulation ────────────────── v0.4.1
#    Installed OrdinaryDiffEqNordsieck ───────────── v1.1.0
#    Installed FastBroadcast ─────────────────────── v0.3.5
#    Installed OrdinaryDiffEqIMEXMultistep ───────── v1.3.0
#    Installed Parameters ────────────────────────── v0.12.3
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [1dea7af3] + OrdinaryDiffEq v6.98.0
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [47edcb42] + ADTypes v1.15.0
#   [7d9f7c33] + Accessors v0.1.42
#   [79e6a3ab] + Adapt v4.3.0
#   [4fba245c] + ArrayInterface v7.19.0
#   [4c555306] + ArrayLayouts v1.11.1
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.6
#   [70df07ce] + BracketingNonlinearSolve v1.3.0
#   [2a0fbf3d] + CPUSummary v0.2.6
#   [d360d2e6] + ChainRulesCore v1.25.2
#   [fb6a15b2] + CloseOpenIntervals v0.1.13
#   [38540f10] + CommonSolve v0.2.4
#   [bbf7d656] + CommonSubexpressions v0.3.1
#   [f70d9fcc] + CommonWorldInvalidations v1.0.0
#   [34da2185] + Compat v4.17.0
#   [a33af91c] + CompositionsBase v0.1.2
#   [2569d6c7] + ConcreteStructs v0.2.3
#   [187b0558] + ConstructionBase v1.6.0
#   [adafc99b] + CpuId v0.3.1
#   [a8cc5b0e] + Crayons v4.1.1
#   [9a962f9c] + DataAPI v1.16.0
#   [864edb3b] + DataStructures v0.18.22
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [2b5f629d] + DiffEqBase v6.177.2
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [a0c0ee7d] + DifferentiationInterface v0.7.2
#   [ffbed154] + DocStringExtensions v0.9.5
#   [4e289a0a] + EnumX v1.0.5
#   [f151be2c] + EnzymeCore v0.8.12
#   [d4d017d3] + ExponentialUtilities v1.27.0
#   [e2ba6199] + ExprTools v0.1.10
#   [55351af7] + ExproniconLite v0.10.14
#   [7034ab61] + FastBroadcast v0.3.5
#   [9aa1b823] + FastClosures v0.3.2
#   [442a2c76] + FastGaussQuadrature v1.0.2
#   [a4df4552] + FastPower v1.1.3
#   [1a297f60] + FillArrays v1.13.0
#   [6a86dc24] + FiniteDiff v2.27.0
#   [f6369f11] + ForwardDiff v1.0.1
#   [069b7b12] + FunctionWrappers v1.1.3
#   [77dc65aa] + FunctionWrappersWrappers v0.1.3
#   [46192b85] + GPUArraysCore v0.2.0
#   [c145ed77] + GenericSchur v0.5.5
#   [615f187c] + IfElse v0.1.1
#   [3587e190] + InverseFunctions v0.1.17
#   [92d709cd] + IrrationalConstants v0.2.4
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [ae98c720] + Jieko v0.2.1
#   [ba0b0d4f] + Krylov v0.10.1
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [10f19ff3] + LayoutPointers v0.1.17
#   [5078a376] + LazyArrays v2.6.1
#   [87fe0de2] + LineSearch v0.1.4
#   [d3d80556] + LineSearches v7.4.0
#   [7ed4a6bd] + LinearSolve v3.18.2
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [1914dd2f] + MacroTools v0.5.16
#   [d125e4d3] + ManualMemory v0.1.8
#   [bb5d69b7] + MaybeInplace v0.1.4
#   [2e0e35c7] + Moshi v0.3.7
#   [46d2c3a1] + MuladdMacro v0.2.4
#   [d41bc354] + NLSolversBase v7.10.0
#   [77ba4419] + NaNMath v1.1.3
#   [8913a72c] + NonlinearSolve v4.9.0
#   [be0214bd] + NonlinearSolveBase v1.12.0
#   [5959db7a] + NonlinearSolveFirstOrder v1.5.0
#   [9a2c21bd] + NonlinearSolveQuasiNewton v1.6.0
#   [26075421] + NonlinearSolveSpectralMethods v1.2.0
#   [bac558e1] + OrderedCollections v1.8.1
#   [1dea7af3] + OrdinaryDiffEq v6.98.0
#   [89bda076] + OrdinaryDiffEqAdamsBashforthMoulton v1.2.0
#   [6ad6398a] + OrdinaryDiffEqBDF v1.6.0
#   [bbf590c4] + OrdinaryDiffEqCore v1.26.2
#   [50262376] + OrdinaryDiffEqDefault v1.5.0
#   [4302a76b] + OrdinaryDiffEqDifferentiation v1.10.0
#   [9286f039] + OrdinaryDiffEqExplicitRK v1.1.0
#   [e0540318] + OrdinaryDiffEqExponentialRK v1.4.0
#   [becaefa8] + OrdinaryDiffEqExtrapolation v1.5.0
#   [5960d6e9] + OrdinaryDiffEqFIRK v1.12.0
#   [101fe9f7] + OrdinaryDiffEqFeagin v1.1.0
#   [d3585ca7] + OrdinaryDiffEqFunctionMap v1.1.1
#   [d28bc4f8] + OrdinaryDiffEqHighOrderRK v1.1.0
#   [9f002381] + OrdinaryDiffEqIMEXMultistep v1.3.0
#   [521117fe] + OrdinaryDiffEqLinear v1.3.0
#   [1344f307] + OrdinaryDiffEqLowOrderRK v1.2.0
#   [b0944070] + OrdinaryDiffEqLowStorageRK v1.3.0
#   [127b3ac7] + OrdinaryDiffEqNonlinearSolve v1.10.0
#   [c9986a66] + OrdinaryDiffEqNordsieck v1.1.0
#   [5dd0a6cf] + OrdinaryDiffEqPDIRK v1.3.1
#   [5b33eab2] + OrdinaryDiffEqPRK v1.1.0
#   [04162be5] + OrdinaryDiffEqQPRK v1.1.0
#   [af6ede74] + OrdinaryDiffEqRKN v1.1.0
#   [43230ef6] + OrdinaryDiffEqRosenbrock v1.11.0
#   [2d112036] + OrdinaryDiffEqSDIRK v1.3.0
#   [669c94d9] + OrdinaryDiffEqSSPRK v1.3.0
#   [e3e12d00] + OrdinaryDiffEqStabilizedIRK v1.3.0
#   [358294b1] + OrdinaryDiffEqStabilizedRK v1.1.0
#   [fa646aed] + OrdinaryDiffEqSymplecticRK v1.3.0
#   [b1df2697] + OrdinaryDiffEqTsit5 v1.1.0
#   [79d7bb75] + OrdinaryDiffEqVerner v1.2.0
#   [d96e819e] + Parameters v0.12.3
#   [f517fe37] + Polyester v0.7.18
#   [1d0040c9] + PolyesterWeave v0.2.2
#   [d236fae5] + PreallocationTools v0.4.28
#   [08abe8d2] + PrettyTables v2.4.0
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [731186ca] + RecursiveArrayTools v3.34.1
#   [189a3867] + Reexport v1.2.2
#   [ae029012] + Requires v1.3.1
#   [7e49a35a] + RuntimeGeneratedFunctions v0.5.15
#   [94e857df] + SIMDTypes v0.1.0
#   [0bca4576] + SciMLBase v2.102.1
#   [19f34311] + SciMLJacobianOperators v0.1.6
#   [c0aeaf25] + SciMLOperators v1.3.1
#   [53ae85a6] + SciMLStructures v1.7.0
#   [efcf1570] + Setfield v1.1.2
#   [727e6d20] + SimpleNonlinearSolve v2.5.0
#   [ce78b400] + SimpleUnPack v1.1.0
#   [0a514795] + SparseMatrixColorings v0.4.21
#   [276daf66] + SpecialFunctions v2.5.1
#   [aedffcd0] + Static v1.2.0
#   [0d7ed370] + StaticArrayInterface v1.8.0
#   [90137ffa] + StaticArrays v1.9.13
#   [1e83bf80] + StaticArraysCore v1.4.3
#   [10745b16] + Statistics v1.11.1
#   [7792a7ef] + StrideArraysCore v0.5.7
#   [892a3eda] + StringManipulation v0.4.1
#   [2efcf032] + SymbolicIndexingInterface v0.3.41
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.1
#   [8290d209] + ThreadingUtilities v0.5.5
#   [a759f4b9] + TimerOutputs v0.5.29
#   [781d530d] + TruncatedStacktraces v1.4.0
#   [3a884ed6] + UnPack v1.0.2
#   [1d5cc7b8] + IntelOpenMP_jll v2025.0.4+0
#   [856f044c] + MKL_jll v2025.0.1+1
#   [efe28fd5] + OpenSpecFun_jll v0.5.6+0
#   [1317d2d5] + oneTBB_jll v2022.0.0+0
#   [8ba89e20] + Distributed v1.11.0
#   [9fa8497b] + Future v1.11.0
#   [4af54fe1] + LazyArtifacts v1.11.0
#   [37e2e46d] + LinearAlgebra v1.11.0
#   [9e88b42a] + Serialization v1.11.0
#   [2f01184e] + SparseArrays v1.11.0
#   [e66e0078] + CompilerSupportLibraries_jll v1.1.1+0
#   [4536629a] + OpenBLAS_jll v0.3.27+1
#   [05823500] + OpenLibm_jll v0.8.5+0
#   [bea87d4a] + SuiteSparse_jll v7.7.0+0
#   [8e850b90] + libblastrampoline_jll v5.11.0+0
# Precompiling project...
#    3673.7 ms  ✓ ConcreteStructs
#    4138.2 ms  ✓ SimpleUnPack
#    3703.9 ms  ✓ MuladdMacro
#    3678.2 ms  ✓ LaTeXStrings
#    3720.1 ms  ✓ FunctionWrappers
#    1143.4 ms  ✓ IteratorInterfaceExtensions
#    1257.5 ms  ✓ UnPack
#    1779.8 ms  ✓ ExprTools
#    2069.0 ms  ✓ ADTypes
#    1506.0 ms  ✓ InverseFunctions
#    1261.6 ms  ✓ CommonSolve
#    2006.0 ms  ✓ Statistics
#    3194.7 ms  ✓ FillArrays
#    1535.2 ms  ✓ ManualMemory
#    2155.1 ms  ✓ OrderedCollections
#    5993.3 ms  ✓ ExproniconLite
#    1332.9 ms  ✓ DataValueInterfaces
#    1657.2 ms  ✓ Requires
#    1051.5 ms  ✓ Reexport
#    1333.3 ms  ✓ EnumX
#    1136.1 ms  ✓ SIMDTypes
#    1578.1 ms  ✓ DocStringExtensions
#    1042.3 ms  ✓ FastPower
#    1062.8 ms  ✓ CompositionsBase
#    1870.7 ms  ✓ NaNMath
#    1757.5 ms  ✓ IfElse
#    7262.9 ms  ✓ MacroTools
#    2090.8 ms  ✓ EnzymeCore
#    3580.9 ms  ✓ IrrationalConstants
#    1508.5 ms  ✓ ConstructionBase
#    1432.1 ms  ✓ CommonWorldInvalidations
#    1419.5 ms  ✓ DataAPI
#    1196.4 ms  ✓ FastClosures
#    1222.1 ms  ✓ StaticArraysCore
#    3288.8 ms  ✓ Crayons
#    1591.7 ms  ✓ Compat
#    2352.0 ms  ✓ CpuId
#    3104.5 ms  ✓ GenericSchur
#    1663.7 ms  ✓ oneTBB_jll
#    3053.1 ms  ✓ OpenSpecFun_jll
#    2045.9 ms  ✓ FunctionWrappersWrappers
#    5162.7 ms  ✓ RecipesBase
#    4647.9 ms  ✓ IntelOpenMP_jll
#    5967.1 ms  ✓ StringManipulation
#    1606.7 ms  ✓ TableTraits
#    2136.7 ms  ✓ RuntimeGeneratedFunctions
#    1656.8 ms  ✓ InverseFunctions → InverseFunctionsDatesExt
#    1910.4 ms  ✓ Statistics → SparseArraysExt
#    3058.6 ms  ✓ DifferentiationInterface
#    1252.4 ms  ✓ FillArrays → FillArraysStatisticsExt
#    2239.4 ms  ✓ FillArrays → FillArraysSparseArraysExt
#    7467.5 ms  ✓ TimerOutputs
#    3047.9 ms  ✓ ThreadingUtilities
#    1926.7 ms  ✓ Parameters
#    1284.5 ms  ✓ Adapt
#    1213.0 ms  ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#    1980.9 ms  ✓ CommonSubexpressions
#    5305.4 ms  ✓ Jieko
#    1927.9 ms  ✓ TruncatedStacktraces
#    1637.5 ms  ✓ ADTypes → ADTypesEnzymeCoreExt
#   23499.0 ms  ✓ Krylov
#    2009.3 ms  ✓ ADTypes → ADTypesConstructionBaseExt
#    2624.5 ms  ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#    2925.9 ms  ✓ LogExpFunctions
#    1124.1 ms  ✓ DiffResults
#    2285.7 ms  ✓ Static
#    1152.9 ms  ✓ Compat → CompatLinearAlgebraExt
#    2380.7 ms  ✓ Tables
#    3508.1 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseArraysExt
#    3554.0 ms  ✓ Adapt → AdaptSparseArraysExt
#   21489.6 ms  ✓ SparseMatrixColorings
#    1980.9 ms  ✓ ArrayInterface
#    2153.6 ms  ✓ GPUArraysCore
#   12150.8 ms  ✓ MKL_jll
#    1462.0 ms  ✓ EnzymeCore → AdaptExt
#    3872.8 ms  ✓ Setfield
#    1634.3 ms  ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#   38413.3 ms  ✓ ArrayLayouts
#    8636.7 ms  ✓ Accessors
#    1513.2 ms  ✓ BitTwiddlingConvenienceFunctions
#   26565.8 ms  ✓ StaticArrays
#    3185.2 ms  ✓ CPUSummary
#    8319.9 ms  ✓ SpecialFunctions
#    4570.9 ms  ✓ DataStructures
#    3919.5 ms  ✓ ChainRulesCore
#    2880.5 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseMatrixColoringsExt
#    1796.9 ms  ✓ MaybeInplace
#    1788.6 ms  ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#    1490.5 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#    4260.7 ms  ✓ StaticArrayInterface
#    1307.2 ms  ✓ SciMLStructures
#    1240.2 ms  ✓ DifferentiationInterface → DifferentiationInterfaceGPUArraysCoreExt
#    1322.8 ms  ✓ ArrayInterface → ArrayInterfaceGPUArraysCoreExt
#    2777.8 ms  ✓ ArrayLayouts → ArrayLayoutsSparseArraysExt
#    2792.2 ms  ✓ Accessors → LinearAlgebraExt
#    3054.4 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    3090.2 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#    2705.4 ms  ✓ DifferentiationInterface → DifferentiationInterfaceStaticArraysExt
#    2689.6 ms  ✓ Adapt → AdaptStaticArraysExt
#   26743.4 ms  ✓ Moshi
#    1970.1 ms  ✓ PolyesterWeave
#    2601.2 ms  ✓ Accessors → StaticArraysExt
#    1992.2 ms  ✓ DiffRules
#    1683.0 ms  ✓ ADTypes → ADTypesChainRulesCoreExt
#    2267.4 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    1837.0 ms  ✓ DifferentiationInterface → DifferentiationInterfaceChainRulesCoreExt
#    5201.4 ms  ✓ FastGaussQuadrature
#    1784.4 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesCoreExt
#    2394.2 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    1761.7 ms  ✓ MaybeInplace → MaybeInplaceSparseArraysExt
#    4134.9 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#    1826.5 ms  ✓ FiniteDiff
#    1537.4 ms  ✓ CloseOpenIntervals
#    2729.0 ms  ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#    1916.7 ms  ✓ LayoutPointers
#    5116.1 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#    5298.5 ms  ✓ SciMLOperators
#    6355.7 ms  ✓ LazyArrays
#    1776.3 ms  ✓ FiniteDiff → FiniteDiffSparseArraysExt
#    1632.7 ms  ✓ DifferentiationInterface → DifferentiationInterfaceFiniteDiffExt
#    2443.7 ms  ✓ FiniteDiff → FiniteDiffStaticArraysExt
#    9615.3 ms  ✓ ForwardDiff
#    2148.9 ms  ✓ SciMLOperators → SciMLOperatorsStaticArraysCoreExt
#    2853.8 ms  ✓ StrideArraysCore
#    2729.4 ms  ✓ SciMLOperators → SciMLOperatorsSparseArraysExt
#    1812.7 ms  ✓ FastPower → FastPowerForwardDiffExt
#    3035.3 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#    4548.8 ms  ✓ LazyArrays → LazyArraysStaticArraysExt
#    2642.8 ms  ✓ DifferentiationInterface → DifferentiationInterfaceForwardDiffExt
#    2754.6 ms  ✓ PreallocationTools
#    2519.1 ms  ✓ Polyester
#    3387.4 ms  ✓ NLSolversBase
#    2384.3 ms  ✓ FastBroadcast
#    5561.3 ms  ✓ LineSearches
#   51653.4 ms  ✓ PrettyTables
#    4227.1 ms  ✓ SymbolicIndexingInterface
#    4951.3 ms  ✓ RecursiveArrayTools
#    3505.1 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#    3632.8 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#    3655.8 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsSparseArraysExt
#   16882.8 ms  ✓ SciMLBase
#    3408.5 ms  ✓ SciMLBase → SciMLBaseChainRulesCoreExt
#    6804.3 ms  ✓ DiffEqBase
#    8218.4 ms  ✓ SciMLJacobianOperators
#    4396.1 ms  ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#    5456.7 ms  ✓ DiffEqBase → DiffEqBaseForwardDiffExt
#    4814.3 ms  ✓ DiffEqBase → DiffEqBaseSparseArraysExt
#   10536.9 ms  ✓ OrdinaryDiffEqCore
#   11188.2 ms  ✓ LineSearch
#    4275.3 ms  ✓ OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
#    4085.3 ms  ✓ LineSearch → LineSearchLineSearchesExt
#   16622.4 ms  ✓ NonlinearSolveBase
#    6523.5 ms  ✓ OrdinaryDiffEqExplicitRK
#    7320.1 ms  ✓ OrdinaryDiffEqHighOrderRK
#    9055.8 ms  ✓ OrdinaryDiffEqStabilizedRK
#    7726.7 ms  ✓ OrdinaryDiffEqSymplecticRK
#   12931.5 ms  ✓ OrdinaryDiffEqSSPRK
#    9909.4 ms  ✓ OrdinaryDiffEqFunctionMap
#   14751.8 ms  ✓ OrdinaryDiffEqLowOrderRK
#  110975.7 ms  ✓ ExponentialUtilities
#    7424.8 ms  ✓ OrdinaryDiffEqPRK
#    8492.3 ms  ✓ OrdinaryDiffEqRKN
#   20698.4 ms  ✓ OrdinaryDiffEqTsit5
#    8838.5 ms  ✓ OrdinaryDiffEqFeagin
#    8288.3 ms  ✓ OrdinaryDiffEqQPRK
#    5876.8 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseMatrixColoringsExt
#   10340.8 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseForwardDiffExt
#   80227.5 ms  ✓ LinearSolve
#    8112.4 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseArraysExt
#   15121.4 ms  ✓ OrdinaryDiffEqLowStorageRK
#    5490.6 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLineSearchExt
#    5277.0 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
#   13351.9 ms  ✓ ExponentialUtilities → ExponentialUtilitiesStaticArraysExt
#   17872.3 ms  ✓ OrdinaryDiffEqAdamsBashforthMoulton
#   13276.0 ms  ✓ OrdinaryDiffEqLinear
#   18185.1 ms  ✓ BracketingNonlinearSolve
#    6514.9 ms  ✓ OrdinaryDiffEqNordsieck
#    8963.3 ms  ✓ LinearSolve → LinearSolveEnzymeExt
#   13042.5 ms  ✓ LinearSolve → LinearSolveForwardDiffExt
#    8322.8 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLinearSolveExt
#   18184.4 ms  ✓ LinearSolve → LinearSolveSparseArraysExt
#    5813.6 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveForwardDiffExt
#   27665.6 ms  ✓ NonlinearSolveSpectralMethods
#   20492.9 ms  ✓ OrdinaryDiffEqDifferentiation
#    6082.6 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveChainRulesCoreExt
#    6614.9 ms  ✓ NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
#  107132.1 ms  ✓ OrdinaryDiffEqVerner
#   46279.6 ms  ✓ NonlinearSolveQuasiNewton
#   22061.7 ms  ✓ OrdinaryDiffEqExtrapolation
#   35820.3 ms  ✓ SimpleNonlinearSolve
#   10558.1 ms  ✓ NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
#    4472.0 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#    4519.0 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
#   72035.4 ms  ✓ NonlinearSolveFirstOrder
#   55176.3 ms  ✓ OrdinaryDiffEqRosenbrock
#   23589.0 ms  ✓ NonlinearSolve
#    9112.0 ms  ✓ OrdinaryDiffEqNonlinearSolve
#   13550.6 ms  ✓ OrdinaryDiffEqIMEXMultistep
#   13756.8 ms  ✓ OrdinaryDiffEqStabilizedIRK
#   14820.5 ms  ✓ OrdinaryDiffEqPDIRK
#   17238.8 ms  ✓ OrdinaryDiffEqSDIRK
#   12029.3 ms  ✓ OrdinaryDiffEqExponentialRK
#   44085.6 ms  ✓ OrdinaryDiffEqFIRK
#   27566.1 ms  ✓ OrdinaryDiffEqBDF
#   50189.2 ms  ✓ OrdinaryDiffEqDefault
#    9068.3 ms  ✓ OrdinaryDiffEq
#   206 dependencies successfully precompiled in 480 seconds. 49 already precompiled.
#   2 dependencies had output during precompilation:
# ┌ MKL_jll
# │   Downloading artifact: IntelOpenMP
# └
# ┌ LinearSolve
# │   Downloading artifact: MKL
# └

# %%
# SciML Tools
using OrdinaryDiffEq, ModelingToolkit, DataDrivenDiffEq, SciMLSensitivity, DataDrivenSparse
using Optimization, OptimizationOptimisers, OptimizationOptimJL, LineSearches
# Out:
# ArgumentError: Package ModelingToolkit not found in current path.
#
# - Run `import Pkg; Pkg.add("ModelingToolkit")` to install the ModelingToolkit package.
#
#
#
# Stacktrace:
#
#   [1] macro expansion
#
#     @ .\loading.jl:2296 [inlined]
#
#   [2] macro expansion
#
#     @ .\lock.jl:273 [inlined]
#
#   [3] __require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:2271
#
#   [4] #invoke_in_world#3
#
#     @ .\essentials.jl:1089 [inlined]
#
#   [5] invoke_in_world
#
#     @ .\essentials.jl:1086 [inlined]
#
#   [6] require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:2260
#
#   [7] eval
#
#     @ .\boot.jl:430 [inlined]
#
#   [8] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base .\loading.jl:2734
#
#   [9] #invokelatest#2
#
#     @ .\essentials.jl:1055 [inlined]
#
#  [10] invokelatest
#
#     @ .\essentials.jl:1052 [inlined]
#
#  [11] (::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer c:\Users\lenovo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:24
#
#  [12] withpath(f::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer c:\Users\lenovo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\repl.jl:276
#
#  [13] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#
#     @ VSCodeServer c:\Users\lenovo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:13
#
#  [14] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#
#     @ VSCodeServer.JSONRPC c:\Users\lenovo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\JSONRPC\src\typed.jl:68
#
#  [15] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#5#10"{String})
#
#     @ VSCodeServer c:\Users\lenovo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\packages\VSCodeServer\src\serve_notebook.jl:147
#
#  [16] top-level scope
#
#     @ c:\Users\lenovo\.vscode\extensions\julialang.language-julia-1.149.2\scripts\notebook\notebook.jl:35

# %%
# Standard Libraries
# using LinearAlgebra, Statistics

# %%
# External Libraries
# using ComponentArrays, Lux, Zygote, Plots, StableRNGs
# gr()
