# %%
import Pkg

# %%
Pkg.add("OrdinaryDiffEq")
# Out:
#     Updating registry at `C:\Users\lenovo\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed FastGaussQuadrature ───────────────── v1.0.2
#    Installed OrdinaryDiffEqRosenbrock ──────────── v1.11.0
#    Installed OrdinaryDiffEqRKN ─────────────────── v1.1.0
#    Installed OrdinaryDiffEqSDIRK ───────────────── v1.3.0
#    Installed TimerOutputs ──────────────────────── v0.5.29
#    Installed Accessors ─────────────────────────── v0.1.42
#    Installed OrdinaryDiffEqStabilizedRK ────────── v1.1.0
#    Installed OrdinaryDiffEqPRK ─────────────────── v1.1.0
#    Installed Polyester ─────────────────────────── v0.7.18
#    Installed NonlinearSolve ────────────────────── v4.9.0
#    Installed SciMLJacobianOperators ────────────── v0.1.6
#    Installed EnumX ─────────────────────────────── v1.0.5
#    Installed FunctionWrappers ──────────────────── v1.1.3
#    Installed MaybeInplace ──────────────────────── v0.1.4
#    Installed StaticArrays ──────────────────────── v1.9.13
#    Installed OrdinaryDiffEqAdamsBashforthMoulton ─ v1.2.0
#    Installed RecursiveArrayTools ───────────────── v3.34.1
#    Installed OrdinaryDiffEqCore ────────────────── v1.26.2
#    Installed Statistics ────────────────────────── v1.11.1
#    Installed IntelOpenMP_jll ───────────────────── v2025.0.4+0
#    Installed MuladdMacro ───────────────────────── v0.2.4
#    Installed FiniteDiff ────────────────────────── v2.27.0
#    Installed SIMDTypes ─────────────────────────── v0.1.0
#    Installed Static ────────────────────────────── v1.2.0
#    Installed OrdinaryDiffEqSSPRK ───────────────── v1.3.0
#    Installed IrrationalConstants ───────────────── v0.2.4
#    Installed OrdinaryDiffEqVerner ──────────────── v1.2.0
#    Installed FastPower ─────────────────────────── v1.1.3
#    Installed DiffEqBase ────────────────────────── v6.177.2
#    Installed OrdinaryDiffEqFIRK ────────────────── v1.12.0
#    Installed NonlinearSolveQuasiNewton ─────────── v1.6.0
#    Installed SimpleUnPack ──────────────────────── v1.1.0
#    Installed CpuId ─────────────────────────────── v0.3.1
#    Installed SciMLBase ─────────────────────────── v2.102.1
#    Installed OrdinaryDiffEqNonlinearSolve ──────── v1.10.0
#    Installed BracketingNonlinearSolve ──────────── v1.3.0
#    Installed SimpleNonlinearSolve ──────────────── v2.5.0
#    Installed ADTypes ───────────────────────────── v1.15.0
#    Installed SpecialFunctions ──────────────────── v2.5.1
#    Installed LineSearch ────────────────────────── v0.1.4
#    Installed LinearSolve ───────────────────────── v3.18.2
#    Installed OrdinaryDiffEq ────────────────────── v6.98.0
#    Installed NonlinearSolveSpectralMethods ─────── v1.2.0
#    Installed IfElse ────────────────────────────── v0.1.1
#    Installed NaNMath ───────────────────────────── v1.1.3
#    Installed ManualMemory ──────────────────────── v0.1.8
#    Installed StaticArraysCore ──────────────────── v1.4.3
#    Installed ThreadingUtilities ────────────────── v0.5.5
#    Installed SparseMatrixColorings ─────────────── v0.4.21
#    Installed NLSolversBase ─────────────────────── v7.10.0
#    Installed DataStructures ────────────────────── v0.18.22
#    Installed ExprTools ─────────────────────────── v0.1.10
#    Installed LazyArrays ────────────────────────── v2.6.1
#    Installed CommonWorldInvalidations ──────────── v1.0.0
#    Installed Compat ────────────────────────────── v4.17.0
#    Installed CommonSubexpressions ──────────────── v0.3.1
#    Installed StaticArrayInterface ──────────────── v1.8.0
#    Installed oneTBB_jll ────────────────────────── v2022.0.0+0
#    Installed OrdinaryDiffEqLinear ──────────────── v1.3.0
#    Installed ArrayLayouts ──────────────────────── v1.11.1
#    Installed BitTwiddlingConvenienceFunctions ──── v0.1.6
#    Installed SciMLStructures ───────────────────── v1.7.0
#    Installed DiffRules ─────────────────────────── v1.15.1
#    Installed FunctionWrappersWrappers ──────────── v0.1.3
#    Installed GenericSchur ──────────────────────── v0.5.5
#    Installed TableTraits ───────────────────────── v1.0.1
#    Installed OrdinaryDiffEqExplicitRK ──────────── v1.1.0
#    Installed OrdinaryDiffEqPDIRK ───────────────── v1.3.1
#    Installed OrdinaryDiffEqQPRK ────────────────── v1.1.0
#    Installed LayoutPointers ────────────────────── v0.1.17
#    Installed DiffResults ───────────────────────── v1.1.0
#    Installed OrdinaryDiffEqFunctionMap ─────────── v1.1.1
#    Installed PrettyTables ──────────────────────── v2.4.0
#    Installed SciMLOperators ────────────────────── v1.3.1
#    Installed NonlinearSolveBase ────────────────── v1.12.0
#    Installed Setfield ──────────────────────────── v1.1.2
#    Installed MKL_jll ───────────────────────────── v2025.0.1+1
#    Installed OrdinaryDiffEqLowOrderRK ──────────── v1.2.0
#    Installed EnzymeCore ────────────────────────── v0.8.12
#    Installed NonlinearSolveFirstOrder ──────────── v1.5.0
#    Installed ConstructionBase ──────────────────── v1.6.0
#    Installed ExproniconLite ────────────────────── v0.10.14
#    Installed OrderedCollections ────────────────── v1.8.1
#    Installed PolyesterWeave ────────────────────── v0.2.2
#    Installed DataValueInterfaces ───────────────── v1.0.0
#    Installed OrdinaryDiffEqExponentialRK ───────── v1.4.0
#    Installed FastClosures ──────────────────────── v0.3.2
#    Installed LineSearches ──────────────────────── v7.4.0
#    Installed ArrayInterface ────────────────────── v7.19.0
#    Installed ChainRulesCore ────────────────────── v1.25.2
#    Installed Reexport ──────────────────────────── v1.2.2
#    Installed OrdinaryDiffEqTsit5 ───────────────── v1.1.0
#    Installed CloseOpenIntervals ────────────────── v0.1.13
#    Installed LogExpFunctions ───────────────────── v0.3.29
#    Installed OrdinaryDiffEqLowStorageRK ────────── v1.3.0
#    Installed OrdinaryDiffEqExtrapolation ───────── v1.5.0
#    Installed PreallocationTools ────────────────── v0.4.28
#    Installed CompositionsBase ──────────────────── v0.1.2
#    Installed MacroTools ────────────────────────── v0.5.16
#    Installed OpenSpecFun_jll ───────────────────── v0.5.6+0
#    Installed OrdinaryDiffEqStabilizedIRK ───────── v1.3.0
#    Installed UnPack ────────────────────────────── v1.0.2
#    Installed InverseFunctions ──────────────────── v0.1.17
#    Installed CommonSolve ───────────────────────── v0.2.4
#    Installed Krylov ────────────────────────────── v0.10.1
#    Installed DocStringExtensions ───────────────── v0.9.5
#    Installed ExponentialUtilities ──────────────── v1.27.0
#    Installed GPUArraysCore ─────────────────────── v0.2.0
#    Installed Crayons ───────────────────────────── v4.1.1
#    Installed Adapt ─────────────────────────────── v4.3.0
#    Installed DifferentiationInterface ──────────── v0.7.2
#    Installed OrdinaryDiffEqBDF ─────────────────── v1.6.0
#    Installed RuntimeGeneratedFunctions ─────────── v0.5.15
#    Installed StrideArraysCore ──────────────────── v0.5.7
#    Installed OrdinaryDiffEqDifferentiation ─────── v1.10.0
#    Installed OrdinaryDiffEqHighOrderRK ─────────── v1.1.0
#    Installed OrdinaryDiffEqFeagin ──────────────── v1.1.0
#    Installed Jieko ─────────────────────────────── v0.2.1
#    Installed CPUSummary ────────────────────────── v0.2.6
#    Installed Tables ────────────────────────────── v1.12.1
#    Installed Moshi ─────────────────────────────── v0.3.7
#    Installed DataAPI ───────────────────────────── v1.16.0
#    Installed TruncatedStacktraces ──────────────── v1.4.0
#    Installed ConcreteStructs ───────────────────── v0.2.3
#    Installed RecipesBase ───────────────────────── v1.3.4
#    Installed IteratorInterfaceExtensions ───────── v1.0.0
#    Installed LaTeXStrings ──────────────────────── v1.4.0
#    Installed SymbolicIndexingInterface ─────────── v0.3.41
#    Installed FillArrays ────────────────────────── v1.13.0
#    Installed ForwardDiff ───────────────────────── v1.0.1
#    Installed OrdinaryDiffEqSymplecticRK ────────── v1.3.0
#    Installed OrdinaryDiffEqDefault ─────────────── v1.5.0
#    Installed Requires ──────────────────────────── v1.3.1
#    Installed StringManipulation ────────────────── v0.4.1
#    Installed OrdinaryDiffEqNordsieck ───────────── v1.1.0
#    Installed FastBroadcast ─────────────────────── v0.3.5
#    Installed OrdinaryDiffEqIMEXMultistep ───────── v1.3.0
#    Installed Parameters ────────────────────────── v0.12.3
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [1dea7af3] + OrdinaryDiffEq v6.98.0
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [47edcb42] + ADTypes v1.15.0
#   [7d9f7c33] + Accessors v0.1.42
#   [79e6a3ab] + Adapt v4.3.0
#   [4fba245c] + ArrayInterface v7.19.0
#   [4c555306] + ArrayLayouts v1.11.1
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.6
#   [70df07ce] + BracketingNonlinearSolve v1.3.0
#   [2a0fbf3d] + CPUSummary v0.2.6
#   [d360d2e6] + ChainRulesCore v1.25.2
#   [fb6a15b2] + CloseOpenIntervals v0.1.13
#   [38540f10] + CommonSolve v0.2.4
#   [bbf7d656] + CommonSubexpressions v0.3.1
#   [f70d9fcc] + CommonWorldInvalidations v1.0.0
#   [34da2185] + Compat v4.17.0
#   [a33af91c] + CompositionsBase v0.1.2
#   [2569d6c7] + ConcreteStructs v0.2.3
#   [187b0558] + ConstructionBase v1.6.0
#   [adafc99b] + CpuId v0.3.1
#   [a8cc5b0e] + Crayons v4.1.1
#   [9a962f9c] + DataAPI v1.16.0
#   [864edb3b] + DataStructures v0.18.22
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [2b5f629d] + DiffEqBase v6.177.2
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [a0c0ee7d] + DifferentiationInterface v0.7.2
#   [ffbed154] + DocStringExtensions v0.9.5
#   [4e289a0a] + EnumX v1.0.5
#   [f151be2c] + EnzymeCore v0.8.12
#   [d4d017d3] + ExponentialUtilities v1.27.0
#   [e2ba6199] + ExprTools v0.1.10
#   [55351af7] + ExproniconLite v0.10.14
#   [7034ab61] + FastBroadcast v0.3.5
#   [9aa1b823] + FastClosures v0.3.2
#   [442a2c76] + FastGaussQuadrature v1.0.2
#   [a4df4552] + FastPower v1.1.3
#   [1a297f60] + FillArrays v1.13.0
#   [6a86dc24] + FiniteDiff v2.27.0
#   [f6369f11] + ForwardDiff v1.0.1
#   [069b7b12] + FunctionWrappers v1.1.3
#   [77dc65aa] + FunctionWrappersWrappers v0.1.3
#   [46192b85] + GPUArraysCore v0.2.0
#   [c145ed77] + GenericSchur v0.5.5
#   [615f187c] + IfElse v0.1.1
#   [3587e190] + InverseFunctions v0.1.17
#   [92d709cd] + IrrationalConstants v0.2.4
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [ae98c720] + Jieko v0.2.1
#   [ba0b0d4f] + Krylov v0.10.1
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [10f19ff3] + LayoutPointers v0.1.17
#   [5078a376] + LazyArrays v2.6.1
#   [87fe0de2] + LineSearch v0.1.4
#   [d3d80556] + LineSearches v7.4.0
#   [7ed4a6bd] + LinearSolve v3.18.2
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [1914dd2f] + MacroTools v0.5.16
#   [d125e4d3] + ManualMemory v0.1.8
#   [bb5d69b7] + MaybeInplace v0.1.4
#   [2e0e35c7] + Moshi v0.3.7
#   [46d2c3a1] + MuladdMacro v0.2.4
#   [d41bc354] + NLSolversBase v7.10.0
#   [77ba4419] + NaNMath v1.1.3
#   [8913a72c] + NonlinearSolve v4.9.0
#   [be0214bd] + NonlinearSolveBase v1.12.0
#   [5959db7a] + NonlinearSolveFirstOrder v1.5.0
#   [9a2c21bd] + NonlinearSolveQuasiNewton v1.6.0
#   [26075421] + NonlinearSolveSpectralMethods v1.2.0
#   [bac558e1] + OrderedCollections v1.8.1
#   [1dea7af3] + OrdinaryDiffEq v6.98.0
#   [89bda076] + OrdinaryDiffEqAdamsBashforthMoulton v1.2.0
#   [6ad6398a] + OrdinaryDiffEqBDF v1.6.0
#   [bbf590c4] + OrdinaryDiffEqCore v1.26.2
#   [50262376] + OrdinaryDiffEqDefault v1.5.0
#   [4302a76b] + OrdinaryDiffEqDifferentiation v1.10.0
#   [9286f039] + OrdinaryDiffEqExplicitRK v1.1.0
#   [e0540318] + OrdinaryDiffEqExponentialRK v1.4.0
#   [becaefa8] + OrdinaryDiffEqExtrapolation v1.5.0
#   [5960d6e9] + OrdinaryDiffEqFIRK v1.12.0
#   [101fe9f7] + OrdinaryDiffEqFeagin v1.1.0
#   [d3585ca7] + OrdinaryDiffEqFunctionMap v1.1.1
#   [d28bc4f8] + OrdinaryDiffEqHighOrderRK v1.1.0
#   [9f002381] + OrdinaryDiffEqIMEXMultistep v1.3.0
#   [521117fe] + OrdinaryDiffEqLinear v1.3.0
#   [1344f307] + OrdinaryDiffEqLowOrderRK v1.2.0
#   [b0944070] + OrdinaryDiffEqLowStorageRK v1.3.0
#   [127b3ac7] + OrdinaryDiffEqNonlinearSolve v1.10.0
#   [c9986a66] + OrdinaryDiffEqNordsieck v1.1.0
#   [5dd0a6cf] + OrdinaryDiffEqPDIRK v1.3.1
#   [5b33eab2] + OrdinaryDiffEqPRK v1.1.0
#   [04162be5] + OrdinaryDiffEqQPRK v1.1.0
#   [af6ede74] + OrdinaryDiffEqRKN v1.1.0
#   [43230ef6] + OrdinaryDiffEqRosenbrock v1.11.0
#   [2d112036] + OrdinaryDiffEqSDIRK v1.3.0
#   [669c94d9] + OrdinaryDiffEqSSPRK v1.3.0
#   [e3e12d00] + OrdinaryDiffEqStabilizedIRK v1.3.0
#   [358294b1] + OrdinaryDiffEqStabilizedRK v1.1.0
#   [fa646aed] + OrdinaryDiffEqSymplecticRK v1.3.0
#   [b1df2697] + OrdinaryDiffEqTsit5 v1.1.0
#   [79d7bb75] + OrdinaryDiffEqVerner v1.2.0
#   [d96e819e] + Parameters v0.12.3
#   [f517fe37] + Polyester v0.7.18
#   [1d0040c9] + PolyesterWeave v0.2.2
#   [d236fae5] + PreallocationTools v0.4.28
#   [08abe8d2] + PrettyTables v2.4.0
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [731186ca] + RecursiveArrayTools v3.34.1
#   [189a3867] + Reexport v1.2.2
#   [ae029012] + Requires v1.3.1
#   [7e49a35a] + RuntimeGeneratedFunctions v0.5.15
#   [94e857df] + SIMDTypes v0.1.0
#   [0bca4576] + SciMLBase v2.102.1
#   [19f34311] + SciMLJacobianOperators v0.1.6
#   [c0aeaf25] + SciMLOperators v1.3.1
#   [53ae85a6] + SciMLStructures v1.7.0
#   [efcf1570] + Setfield v1.1.2
#   [727e6d20] + SimpleNonlinearSolve v2.5.0
#   [ce78b400] + SimpleUnPack v1.1.0
#   [0a514795] + SparseMatrixColorings v0.4.21
#   [276daf66] + SpecialFunctions v2.5.1
#   [aedffcd0] + Static v1.2.0
#   [0d7ed370] + StaticArrayInterface v1.8.0
#   [90137ffa] + StaticArrays v1.9.13
#   [1e83bf80] + StaticArraysCore v1.4.3
#   [10745b16] + Statistics v1.11.1
#   [7792a7ef] + StrideArraysCore v0.5.7
#   [892a3eda] + StringManipulation v0.4.1
#   [2efcf032] + SymbolicIndexingInterface v0.3.41
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.1
#   [8290d209] + ThreadingUtilities v0.5.5
#   [a759f4b9] + TimerOutputs v0.5.29
#   [781d530d] + TruncatedStacktraces v1.4.0
#   [3a884ed6] + UnPack v1.0.2
#   [1d5cc7b8] + IntelOpenMP_jll v2025.0.4+0
#   [856f044c] + MKL_jll v2025.0.1+1
#   [efe28fd5] + OpenSpecFun_jll v0.5.6+0
#   [1317d2d5] + oneTBB_jll v2022.0.0+0
#   [8ba89e20] + Distributed v1.11.0
#   [9fa8497b] + Future v1.11.0
#   [4af54fe1] + LazyArtifacts v1.11.0
#   [37e2e46d] + LinearAlgebra v1.11.0
#   [9e88b42a] + Serialization v1.11.0
#   [2f01184e] + SparseArrays v1.11.0
#   [e66e0078] + CompilerSupportLibraries_jll v1.1.1+0
#   [4536629a] + OpenBLAS_jll v0.3.27+1
#   [05823500] + OpenLibm_jll v0.8.5+0
#   [bea87d4a] + SuiteSparse_jll v7.7.0+0
#   [8e850b90] + libblastrampoline_jll v5.11.0+0
# Precompiling project...
#    3673.7 ms  ✓ ConcreteStructs
#    4138.2 ms  ✓ SimpleUnPack
#    3703.9 ms  ✓ MuladdMacro
#    3678.2 ms  ✓ LaTeXStrings
#    3720.1 ms  ✓ FunctionWrappers
#    1143.4 ms  ✓ IteratorInterfaceExtensions
#    1257.5 ms  ✓ UnPack
#    1779.8 ms  ✓ ExprTools
#    2069.0 ms  ✓ ADTypes
#    1506.0 ms  ✓ InverseFunctions
#    1261.6 ms  ✓ CommonSolve
#    2006.0 ms  ✓ Statistics
#    3194.7 ms  ✓ FillArrays
#    1535.2 ms  ✓ ManualMemory
#    2155.1 ms  ✓ OrderedCollections
#    5993.3 ms  ✓ ExproniconLite
#    1332.9 ms  ✓ DataValueInterfaces
#    1657.2 ms  ✓ Requires
#    1051.5 ms  ✓ Reexport
#    1333.3 ms  ✓ EnumX
#    1136.1 ms  ✓ SIMDTypes
#    1578.1 ms  ✓ DocStringExtensions
#    1042.3 ms  ✓ FastPower
#    1062.8 ms  ✓ CompositionsBase
#    1870.7 ms  ✓ NaNMath
#    1757.5 ms  ✓ IfElse
#    7262.9 ms  ✓ MacroTools
#    2090.8 ms  ✓ EnzymeCore
#    3580.9 ms  ✓ IrrationalConstants
#    1508.5 ms  ✓ ConstructionBase
#    1432.1 ms  ✓ CommonWorldInvalidations
#    1419.5 ms  ✓ DataAPI
#    1196.4 ms  ✓ FastClosures
#    1222.1 ms  ✓ StaticArraysCore
#    3288.8 ms  ✓ Crayons
#    1591.7 ms  ✓ Compat
#    2352.0 ms  ✓ CpuId
#    3104.5 ms  ✓ GenericSchur
#    1663.7 ms  ✓ oneTBB_jll
#    3053.1 ms  ✓ OpenSpecFun_jll
#    2045.9 ms  ✓ FunctionWrappersWrappers
#    5162.7 ms  ✓ RecipesBase
#    4647.9 ms  ✓ IntelOpenMP_jll
#    5967.1 ms  ✓ StringManipulation
#    1606.7 ms  ✓ TableTraits
#    2136.7 ms  ✓ RuntimeGeneratedFunctions
#    1656.8 ms  ✓ InverseFunctions → InverseFunctionsDatesExt
#    1910.4 ms  ✓ Statistics → SparseArraysExt
#    3058.6 ms  ✓ DifferentiationInterface
#    1252.4 ms  ✓ FillArrays → FillArraysStatisticsExt
#    2239.4 ms  ✓ FillArrays → FillArraysSparseArraysExt
#    7467.5 ms  ✓ TimerOutputs
#    3047.9 ms  ✓ ThreadingUtilities
#    1926.7 ms  ✓ Parameters
#    1284.5 ms  ✓ Adapt
#    1213.0 ms  ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#    1980.9 ms  ✓ CommonSubexpressions
#    5305.4 ms  ✓ Jieko
#    1927.9 ms  ✓ TruncatedStacktraces
#    1637.5 ms  ✓ ADTypes → ADTypesEnzymeCoreExt
#   23499.0 ms  ✓ Krylov
#    2009.3 ms  ✓ ADTypes → ADTypesConstructionBaseExt
#    2624.5 ms  ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#    2925.9 ms  ✓ LogExpFunctions
#    1124.1 ms  ✓ DiffResults
#    2285.7 ms  ✓ Static
#    1152.9 ms  ✓ Compat → CompatLinearAlgebraExt
#    2380.7 ms  ✓ Tables
#    3508.1 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseArraysExt
#    3554.0 ms  ✓ Adapt → AdaptSparseArraysExt
#   21489.6 ms  ✓ SparseMatrixColorings
#    1980.9 ms  ✓ ArrayInterface
#    2153.6 ms  ✓ GPUArraysCore
#   12150.8 ms  ✓ MKL_jll
#    1462.0 ms  ✓ EnzymeCore → AdaptExt
#    3872.8 ms  ✓ Setfield
#    1634.3 ms  ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#   38413.3 ms  ✓ ArrayLayouts
#    8636.7 ms  ✓ Accessors
#    1513.2 ms  ✓ BitTwiddlingConvenienceFunctions
#   26565.8 ms  ✓ StaticArrays
#    3185.2 ms  ✓ CPUSummary
#    8319.9 ms  ✓ SpecialFunctions
#    4570.9 ms  ✓ DataStructures
#    3919.5 ms  ✓ ChainRulesCore
#    2880.5 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseMatrixColoringsExt
#    1796.9 ms  ✓ MaybeInplace
#    1788.6 ms  ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#    1490.5 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#    4260.7 ms  ✓ StaticArrayInterface
#    1307.2 ms  ✓ SciMLStructures
#    1240.2 ms  ✓ DifferentiationInterface → DifferentiationInterfaceGPUArraysCoreExt
#    1322.8 ms  ✓ ArrayInterface → ArrayInterfaceGPUArraysCoreExt
#    2777.8 ms  ✓ ArrayLayouts → ArrayLayoutsSparseArraysExt
#    2792.2 ms  ✓ Accessors → LinearAlgebraExt
#    3054.4 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    3090.2 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#    2705.4 ms  ✓ DifferentiationInterface → DifferentiationInterfaceStaticArraysExt
#    2689.6 ms  ✓ Adapt → AdaptStaticArraysExt
#   26743.4 ms  ✓ Moshi
#    1970.1 ms  ✓ PolyesterWeave
#    2601.2 ms  ✓ Accessors → StaticArraysExt
#    1992.2 ms  ✓ DiffRules
#    1683.0 ms  ✓ ADTypes → ADTypesChainRulesCoreExt
#    2267.4 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    1837.0 ms  ✓ DifferentiationInterface → DifferentiationInterfaceChainRulesCoreExt
#    5201.4 ms  ✓ FastGaussQuadrature
#    1784.4 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesCoreExt
#    2394.2 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    1761.7 ms  ✓ MaybeInplace → MaybeInplaceSparseArraysExt
#    4134.9 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#    1826.5 ms  ✓ FiniteDiff
#    1537.4 ms  ✓ CloseOpenIntervals
#    2729.0 ms  ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#    1916.7 ms  ✓ LayoutPointers
#    5116.1 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#    5298.5 ms  ✓ SciMLOperators
#    6355.7 ms  ✓ LazyArrays
#    1776.3 ms  ✓ FiniteDiff → FiniteDiffSparseArraysExt
#    1632.7 ms  ✓ DifferentiationInterface → DifferentiationInterfaceFiniteDiffExt
#    2443.7 ms  ✓ FiniteDiff → FiniteDiffStaticArraysExt
#    9615.3 ms  ✓ ForwardDiff
#    2148.9 ms  ✓ SciMLOperators → SciMLOperatorsStaticArraysCoreExt
#    2853.8 ms  ✓ StrideArraysCore
#    2729.4 ms  ✓ SciMLOperators → SciMLOperatorsSparseArraysExt
#    1812.7 ms  ✓ FastPower → FastPowerForwardDiffExt
#    3035.3 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#    4548.8 ms  ✓ LazyArrays → LazyArraysStaticArraysExt
#    2642.8 ms  ✓ DifferentiationInterface → DifferentiationInterfaceForwardDiffExt
#    2754.6 ms  ✓ PreallocationTools
#    2519.1 ms  ✓ Polyester
#    3387.4 ms  ✓ NLSolversBase
#    2384.3 ms  ✓ FastBroadcast
#    5561.3 ms  ✓ LineSearches
#   51653.4 ms  ✓ PrettyTables
#    4227.1 ms  ✓ SymbolicIndexingInterface
#    4951.3 ms  ✓ RecursiveArrayTools
#    3505.1 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#    3632.8 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#    3655.8 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsSparseArraysExt
#   16882.8 ms  ✓ SciMLBase
#    3408.5 ms  ✓ SciMLBase → SciMLBaseChainRulesCoreExt
#    6804.3 ms  ✓ DiffEqBase
#    8218.4 ms  ✓ SciMLJacobianOperators
#    4396.1 ms  ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#    5456.7 ms  ✓ DiffEqBase → DiffEqBaseForwardDiffExt
#    4814.3 ms  ✓ DiffEqBase → DiffEqBaseSparseArraysExt
#   10536.9 ms  ✓ OrdinaryDiffEqCore
#   11188.2 ms  ✓ LineSearch
#    4275.3 ms  ✓ OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
#    4085.3 ms  ✓ LineSearch → LineSearchLineSearchesExt
#   16622.4 ms  ✓ NonlinearSolveBase
#    6523.5 ms  ✓ OrdinaryDiffEqExplicitRK
#    7320.1 ms  ✓ OrdinaryDiffEqHighOrderRK
#    9055.8 ms  ✓ OrdinaryDiffEqStabilizedRK
#    7726.7 ms  ✓ OrdinaryDiffEqSymplecticRK
#   12931.5 ms  ✓ OrdinaryDiffEqSSPRK
#    9909.4 ms  ✓ OrdinaryDiffEqFunctionMap
#   14751.8 ms  ✓ OrdinaryDiffEqLowOrderRK
#  110975.7 ms  ✓ ExponentialUtilities
#    7424.8 ms  ✓ OrdinaryDiffEqPRK
#    8492.3 ms  ✓ OrdinaryDiffEqRKN
#   20698.4 ms  ✓ OrdinaryDiffEqTsit5
#    8838.5 ms  ✓ OrdinaryDiffEqFeagin
#    8288.3 ms  ✓ OrdinaryDiffEqQPRK
#    5876.8 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseMatrixColoringsExt
#   10340.8 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseForwardDiffExt
#   80227.5 ms  ✓ LinearSolve
#    8112.4 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseArraysExt
#   15121.4 ms  ✓ OrdinaryDiffEqLowStorageRK
#    5490.6 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLineSearchExt
#    5277.0 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
#   13351.9 ms  ✓ ExponentialUtilities → ExponentialUtilitiesStaticArraysExt
#   17872.3 ms  ✓ OrdinaryDiffEqAdamsBashforthMoulton
#   13276.0 ms  ✓ OrdinaryDiffEqLinear
#   18185.1 ms  ✓ BracketingNonlinearSolve
#    6514.9 ms  ✓ OrdinaryDiffEqNordsieck
#    8963.3 ms  ✓ LinearSolve → LinearSolveEnzymeExt
#   13042.5 ms  ✓ LinearSolve → LinearSolveForwardDiffExt
#    8322.8 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLinearSolveExt
#   18184.4 ms  ✓ LinearSolve → LinearSolveSparseArraysExt
#    5813.6 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveForwardDiffExt
#   27665.6 ms  ✓ NonlinearSolveSpectralMethods
#   20492.9 ms  ✓ OrdinaryDiffEqDifferentiation
#    6082.6 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveChainRulesCoreExt
#    6614.9 ms  ✓ NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
#  107132.1 ms  ✓ OrdinaryDiffEqVerner
#   46279.6 ms  ✓ NonlinearSolveQuasiNewton
#   22061.7 ms  ✓ OrdinaryDiffEqExtrapolation
#   35820.3 ms  ✓ SimpleNonlinearSolve
#   10558.1 ms  ✓ NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
#    4472.0 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#    4519.0 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
#   72035.4 ms  ✓ NonlinearSolveFirstOrder
#   55176.3 ms  ✓ OrdinaryDiffEqRosenbrock
#   23589.0 ms  ✓ NonlinearSolve
#    9112.0 ms  ✓ OrdinaryDiffEqNonlinearSolve
#   13550.6 ms  ✓ OrdinaryDiffEqIMEXMultistep
#   13756.8 ms  ✓ OrdinaryDiffEqStabilizedIRK
#   14820.5 ms  ✓ OrdinaryDiffEqPDIRK
#   17238.8 ms  ✓ OrdinaryDiffEqSDIRK
#   12029.3 ms  ✓ OrdinaryDiffEqExponentialRK
#   44085.6 ms  ✓ OrdinaryDiffEqFIRK
#   27566.1 ms  ✓ OrdinaryDiffEqBDF
#   50189.2 ms  ✓ OrdinaryDiffEqDefault
#    9068.3 ms  ✓ OrdinaryDiffEq
#   206 dependencies successfully precompiled in 480 seconds. 49 already precompiled.
#   2 dependencies had output during precompilation:
# ┌ MKL_jll
# │   Downloading artifact: IntelOpenMP
# └
# ┌ LinearSolve
# │   Downloading artifact: MKL
# └

# %%
Pkg.add("ModelingToolkit")
Pkg.add("DataDrivenDiffEq")
Pkg.add("SciMLSensitivity")
Pkg.add("DataDrivenSparse")
Pkg.add("Optimization")
Pkg.add("OptimizationOptimisers")
Pkg.add("OptimizationOptimJL")
Pkg.add("LineSearches")
# Out:
#    Resolving package versions...
#    Installed HypergeometricFunctions ─ v0.3.28
#    Installed SciMLPublic ───────────── v1.0.0
#    Installed StatsFuns ─────────────── v1.5.0
#    Installed OffsetArrays ──────────── v1.17.0
#    Installed Unitful ───────────────── v1.23.1
#    Installed MutableArithmetics ────── v1.6.4
#    Installed DomainSets ────────────── v0.7.15
#    Installed JuliaFormatter ────────── v2.1.2
#    Installed Functors ──────────────── v0.5.2
#    Installed Bijections ────────────── v0.2.2
#    Installed FindFirstFunctions ────── v1.4.1
#    Installed ArnoldiMethod ─────────── v0.4.0
#    Installed PDMats ────────────────── v0.11.35
#    Installed Missings ──────────────── v1.2.0
#    Installed Tricks ────────────────── v0.1.10
#    Installed MultivariatePolynomials ─ v0.5.9
#    Installed RandomNumbers ─────────── v1.6.0
#    Installed CompositeTypes ────────── v0.1.4
#    Installed PtrArrays ─────────────── v1.3.0
#    Installed Rmath_jll ─────────────── v0.5.1+0
#    Installed DiffEqNoiseProcess ────── v5.24.1
#    Installed JuliaSyntax ───────────── v0.4.10
#    Installed Random123 ─────────────── v1.7.1
#    Installed JumpProcesses ─────────── v9.16.1
#    Installed Symbolics ─────────────── v6.43.0
#    Installed CommonMark ────────────── v0.9.1
#    Installed StatsAPI ──────────────── v1.7.1
#    Installed Graphs ────────────────── v1.13.0
#    Installed DynamicPolynomials ────── v0.6.2
#    Installed Inflate ───────────────── v0.1.5
#    Installed ImplicitDiscreteSolve ─── v0.1.2
#    Installed Glob ──────────────────── v1.3.1
#    Installed StatsBase ─────────────── v0.34.5
#    Installed MLStyle ───────────────── v0.4.17
#    Installed DispatchDoctor ────────── v0.4.26
#    Installed PositiveFactorizations ── v0.2.4
#    Installed DiffEqCallbacks ───────── v4.8.0
#    Installed ModelingToolkit ───────── v10.10.0
#    Installed Format ────────────────── v1.3.7
#    Installed AbstractTrees ─────────── v0.4.5
#    Installed SymbolicLimits ────────── v0.2.2
#    Installed Combinatorics ─────────── v1.0.3
#    Installed AliasTables ───────────── v1.1.3
#    Installed SimpleTraits ──────────── v0.9.4
#    Installed TaskLocalValues ───────── v0.1.3
#    Installed SCCNonlinearSolve ─────── v1.3.1
#    Installed Rmath ─────────────────── v0.8.0
#    Installed IntervalSets ──────────── v0.7.11
#    Installed Primes ────────────────── v0.5.7
#    Installed IntegerMathUtils ──────── v0.1.3
#    Installed TermInterface ─────────── v2.0.0
#    Installed SymbolicUtils ─────────── v3.29.0
#    Installed Latexify ──────────────── v0.16.8
#    Installed BlockArrays ───────────── v1.7.0
#    Installed Optim ─────────────────── v1.13.2
#    Installed URIs ──────────────────── v1.6.1
#    Installed Unityper ──────────────── v0.1.6
#    Installed WeakValueDicts ────────── v0.1.0
#    Installed PoissonRandom ─────────── v0.4.5
#    Installed TestItems ─────────────── v1.0.0
#    Installed ResettableStacks ──────── v1.1.1
#    Installed ForwardDiff ───────────── v0.10.38
#    Installed QuadGK ────────────────── v2.11.2
#    Installed DynamicQuantities ─────── v1.8.0
#    Installed SortingAlgorithms ─────── v1.2.1
#    Installed Distributions ─────────── v0.25.120
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [961ee093] + ModelingToolkit v10.10.0
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [1520ce14] + AbstractTrees v0.4.5
#   [66dad0bd] + AliasTables v1.1.3
#   [ec485272] + ArnoldiMethod v0.4.0
#   [e2ed5e7c] + Bijections v0.2.2
#   [8e7c35d0] + BlockArrays v1.7.0
#   [861a8166] + Combinatorics v1.0.3
#   [a80b9123] + CommonMark v0.9.1
#   [b152e2b5] + CompositeTypes v0.1.4
#   [459566f4] + DiffEqCallbacks v4.8.0
#   [77a26b50] + DiffEqNoiseProcess v5.24.1
#   [8d63f2c5] + DispatchDoctor v0.4.26
#   [31c24e10] + Distributions v0.25.120
#   [5b8099bc] + DomainSets v0.7.15
#   [7c1d4256] + DynamicPolynomials v0.6.2
#   [06fc5a27] + DynamicQuantities v1.8.0
#   [64ca27bc] + FindFirstFunctions v1.4.1
#   [1fa38f19] + Format v1.3.7
# ⌅ [f6369f11] ↓ ForwardDiff v1.0.1 ⇒ v0.10.38
#   [d9f16b24] + Functors v0.5.2
#   [c27321d9] + Glob v1.3.1
#   [86223c79] + Graphs v1.13.0
#   [34004b35] + HypergeometricFunctions v0.3.28
#   [3263718b] + ImplicitDiscreteSolve v0.1.2
#   [d25df0c9] + Inflate v0.1.5
#   [18e54dd8] + IntegerMathUtils v0.1.3
#   [8197267c] + IntervalSets v0.7.11
#   [98e50ef6] + JuliaFormatter v2.1.2
# ⌅ [70703baa] + JuliaSyntax v0.4.10
#   [ccbc3e58] + JumpProcesses v9.16.1
#   [23fbe1c1] + Latexify v0.16.8
#   [d8e11817] + MLStyle v0.4.17
#   [e1d29d7a] + Missings v1.2.0
#   [961ee093] + ModelingToolkit v10.10.0
#   [102ac46a] + MultivariatePolynomials v0.5.9
#   [d8a4904e] + MutableArithmetics v1.6.4
#   [6fe1bfb0] + OffsetArrays v1.17.0
#   [429524aa] + Optim v1.13.2
#   [90014a1f] + PDMats v0.11.35
#   [e409e4f3] + PoissonRandom v0.4.5
#   [85a6dd25] + PositiveFactorizations v0.2.4
#   [27ebfcd6] + Primes v0.5.7
#   [43287f4e] + PtrArrays v1.3.0
#   [1fd47b50] + QuadGK v2.11.2
#   [74087812] + Random123 v1.7.1
#   [e6cf234a] + RandomNumbers v1.6.0
#   [ae5879a3] + ResettableStacks v1.1.1
#   [79098fc4] + Rmath v0.8.0
#   [9dfe8606] + SCCNonlinearSolve v1.3.1
#   [431bcebd] + SciMLPublic v1.0.0
#   [699a6c99] + SimpleTraits v0.9.4
#   [a2af1166] + SortingAlgorithms v1.2.1
#   [82ae8749] + StatsAPI v1.7.1
#   [2913bbd2] + StatsBase v0.34.5
#   [4c63d2b9] + StatsFuns v1.5.0
#   [19f23fe9] + SymbolicLimits v0.2.2
#   [d1185830] + SymbolicUtils v3.29.0
#   [0c5d862f] + Symbolics v6.43.0
#   [ed4db957] + TaskLocalValues v0.1.3
#   [8ea1fca8] + TermInterface v2.0.0
#   [1c621080] + TestItems v1.0.0
#   [410a4b4d] + Tricks v0.1.10
#   [5c2747f8] + URIs v1.6.1
#   [1986cc42] + Unitful v1.23.1
#   [a7c27f48] + Unityper v0.1.6
#   [897b6980] + WeakValueDicts v0.1.0
#   [f50d1b31] + Rmath_jll v0.5.1+0
#   [1a1011a3] + SharedArrays v1.11.0
#   [4607b0f0] + SuiteSparse
#   [8dfed614] + Test v1.11.0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   18064.3 ms  ✓ Combinatorics
#   15778.7 ms  ✓ PositiveFactorizations
#   15771.8 ms  ✓ Glob
#   15764.3 ms  ✓ Tricks
#   15756.7 ms  ✓ StatsAPI
#    1290.8 ms  ✓ IntegerMathUtils
#    3092.3 ms  ✓ OffsetArrays
#    1829.5 ms  ✓ CompositeTypes
#    3102.1 ms  ✓ RandomNumbers
#    3270.3 ms  ✓ Format
#    1168.1 ms  ✓ WeakValueDicts
#    2142.2 ms  ✓ IntervalSets
#    2176.9 ms  ✓ AbstractTrees
#    2587.6 ms  ✓ URIs
#    1544.0 ms  ✓ TestItems
#    1457.1 ms  ✓ PtrArrays
#    1453.5 ms  ✓ TaskLocalValues
#    1345.0 ms  ✓ Inflate
#    1410.0 ms  ✓ TermInterface
#    1454.5 ms  ✓ SciMLPublic
#    1465.0 ms  ✓ FindFirstFunctions
#    1616.9 ms  ✓ Bijections
#    2599.9 ms  ✓ Missings
#    2597.7 ms  ✓ SuiteSparse
#    1567.3 ms  ✓ PoissonRandom
#    1822.1 ms  ✓ Unityper
#    4728.1 ms  ✓ BlockArrays
#    2896.6 ms  ✓ SimpleTraits
#    2132.5 ms  ✓ Functors
#    3684.1 ms  ✓ DispatchDoctor
#    2804.2 ms  ✓ InverseFunctions → InverseFunctionsTestExt
#    2734.5 ms  ✓ Accessors → TestExt
#    2738.8 ms  ✓ Rmath_jll
#   17238.9 ms  ✓ MutableArithmetics
#    6048.9 ms  ✓ ArnoldiMethod
#   43621.4 ms  ✓ JuliaSyntax
#    2840.6 ms  ✓ SortingAlgorithms
#    3450.0 ms  ✓ ResettableStacks
#   42761.5 ms  ✓ MLStyle
#    3453.5 ms  ✓ QuadGK
#    4299.7 ms  ✓ HypergeometricFunctions
#    2533.1 ms  ✓ Primes
#    2572.7 ms  ✓ OffsetArrays → OffsetArraysAdaptExt
#    6005.7 ms  ✓ SCCNonlinearSolve
#   31860.5 ms  ✓ CommonMark
#    4002.2 ms  ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   11433.9 ms  ✓ ForwardDiff
#    3984.6 ms  ✓ Random123
#   52991.7 ms  ✓ Unitful
#    6608.6 ms  ✓ Latexify
#    1887.3 ms  ✓ IntervalSets → IntervalSetsRandomExt
#    1850.6 ms  ✓ IntervalSets → IntervalSetsStatisticsExt
#    2564.1 ms  ✓ ConstructionBase → ConstructionBaseIntervalSetsExt
#    2865.4 ms  ✓ IntervalSets → IntervalSetsRecipesBaseExt
#    2461.1 ms  ✓ Accessors → IntervalSetsExt
#    1564.9 ms  ✓ AliasTables
#    2129.4 ms  ✓ PDMats
#    1920.0 ms  ✓ BlockArrays → BlockArraysAdaptExt
#    1676.5 ms  ✓ DispatchDoctor → DispatchDoctorEnzymeCoreExt
#    3346.3 ms  ✓ LazyArrays → LazyArraysBlockArraysExt
#    2132.3 ms  ✓ DispatchDoctor → DispatchDoctorChainRulesCoreExt
#    1980.9 ms  ✓ Rmath
#    4089.5 ms  ✓ SciMLBase → SciMLBaseMLStyleExt
#    9837.3 ms  ✓ DiffEqCallbacks
#    7189.1 ms  ✓ MultivariatePolynomials
#    2694.1 ms  ✓ FastPower → FastPowerForwardDiffExt
#    3601.7 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#   10345.8 ms  ✓ Graphs
#   14066.4 ms  ✓ DynamicQuantities
#    3251.2 ms  ✓ DifferentiationInterface → DifferentiationInterfaceForwardDiffExt
#    3687.2 ms  ✓ PreallocationTools
#    3814.2 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#    5189.5 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseForwardDiffExt
#    4522.8 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveForwardDiffExt
#    6851.5 ms  ✓ DiffEqBase → DiffEqBaseForwardDiffExt
#    5221.2 ms  ✓ NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
#    3029.4 ms  ✓ Unitful → ConstructionBaseUnitfulExt
#    3015.9 ms  ✓ Unitful → InverseFunctionsUnitfulExt
#   13953.1 ms  ✓ LinearSolve → LinearSolveForwardDiffExt
#    4268.9 ms  ✓ Unitful → PrintfExt
#    4257.3 ms  ✓ Unitful → ForwardDiffExt
#   10599.9 ms  ✓ NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
#    2901.7 ms  ✓ Accessors → UnitfulExt
#    2039.7 ms  ✓ Latexify → SparseArraysExt
#    2068.6 ms  ✓ FillArrays → FillArraysPDMatsExt
#    4648.0 ms  ✓ DiffEqBase → DiffEqBaseUnitfulExt
#    5319.0 ms  ✓ StatsBase
#    6099.0 ms  ✓ DomainSets
#    4066.9 ms  ✓ StatsFuns
#    4892.9 ms  ✓ DynamicPolynomials
#    2347.9 ms  ✓ DynamicQuantities → DynamicQuantitiesLinearAlgebraExt
#    4521.7 ms  ✓ DynamicQuantities → DynamicQuantitiesUnitfulExt
#    2998.5 ms  ✓ NLSolversBase
#    4846.3 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveChainRulesCoreExt
#    9865.5 ms  ✓ JumpProcesses
#    2023.2 ms  ✓ StatsFuns → StatsFunsInverseFunctionsExt
#    4796.3 ms  ✓ StatsFuns → StatsFunsChainRulesCoreExt
#   16948.1 ms  ✓ OrdinaryDiffEqDifferentiation
#   17931.1 ms  ✓ Distributions
#   32619.9 ms  ✓ SimpleNonlinearSolve
#   68895.5 ms  ✓ JuliaFormatter
#    6716.1 ms  ✓ LineSearches
#    4112.0 ms  ✓ Distributions → DistributionsTestExt
#    3685.4 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#    5561.3 ms  ✓ DiffEqBase → DiffEqBaseDistributionsExt
#   18025.7 ms  ✓ OrdinaryDiffEqExtrapolation
#    5141.6 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
#    5021.1 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#    4393.0 ms  ✓ LineSearch → LineSearchLineSearchesExt
#    7996.1 ms  ✓ Optim
#    7586.8 ms  ✓ ImplicitDiscreteSolve
#   72614.8 ms  ✓ NonlinearSolveFirstOrder
#   15512.0 ms  ✓ DiffEqNoiseProcess
#   60708.2 ms  ✓ SymbolicUtils
#    8735.2 ms  ✓ SymbolicLimits
#   58547.4 ms  ✓ OrdinaryDiffEqRosenbrock
#   28751.4 ms  ✓ NonlinearSolve
#   10201.2 ms  ✓ OrdinaryDiffEqNonlinearSolve
#   39066.9 ms  ✓ Symbolics
#   15917.0 ms  ✓ OrdinaryDiffEqIMEXMultistep
#   18008.1 ms  ✓ OrdinaryDiffEqStabilizedIRK
#   20636.0 ms  ✓ OrdinaryDiffEqSDIRK
#   15203.5 ms  ✓ OrdinaryDiffEqPDIRK
#    8699.4 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSymbolicsExt
#    9667.2 ms  ✓ Symbolics → SymbolicsForwardDiffExt
#    8922.1 ms  ✓ Symbolics → SymbolicsPreallocationToolsExt
#   14484.4 ms  ✓ OrdinaryDiffEqExponentialRK
#   51973.9 ms  ✓ OrdinaryDiffEqFIRK
#   30352.1 ms  ✓ OrdinaryDiffEqBDF
#   52271.3 ms  ✓ OrdinaryDiffEqDefault
#   11075.7 ms  ✓ OrdinaryDiffEq
#  168109.4 ms  ✓ ModelingToolkit
#   132 dependencies successfully precompiled in 495 seconds. 223 already precompiled.
#    Resolving package versions...
#    Installed ProgressMeter ──────── v1.10.4
#    Installed ShowCases ──────────── v0.1.0
#    Installed ContextVariablesX ──── v0.1.3
#    Installed ScopedValues ───────── v1.3.0
#    Installed DelimitedFiles ─────── v1.9.1
#    Installed InitialValues ──────── v0.3.1
#    Installed NNlib ──────────────── v0.9.30
#    Installed DataDrivenDiffEq ───── v1.9.0
#    Installed PrettyPrint ────────── v0.2.0
#    Installed MLUtils ────────────── v0.4.8
#    Installed MLCore ─────────────── v1.0.0
#    Installed MicroCollections ───── v0.2.0
#    Installed FLoopsBase ─────────── v0.1.1
#    Installed NameResolution ─────── v0.1.5
#    Installed DefineSingletons ───── v0.1.2
#    Installed BangBang ───────────── v0.4.4
#    Installed FLoops ─────────────── v0.2.2
#    Installed ArgCheck ───────────── v2.5.0
#    Installed Atomix ─────────────── v1.1.1
#    Installed HashArrayMappedTries ─ v0.2.0
#    Installed JuliaVariables ─────── v0.2.4
#    Installed KernelAbstractions ─── v0.9.37
#    Installed UnsafeAtomics ──────── v0.3.0
#    Installed SplittablesBase ────── v0.1.15
#    Installed DataInterpolations ─── v8.1.0
#    Installed Baselet ────────────── v0.1.1
#    Installed Transducers ────────── v0.4.84
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [2445eb08] + DataDrivenDiffEq v1.9.0
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [dce04be8] + ArgCheck v2.5.0
#   [a9b6321e] + Atomix v1.1.1
#   [198e06fe] + BangBang v0.4.4
#   [9718e550] + Baselet v0.1.1
#   [6add18c4] + ContextVariablesX v0.1.3
#   [2445eb08] + DataDrivenDiffEq v1.9.0
#   [82cc6244] + DataInterpolations v8.1.0
#   [244e2a9f] + DefineSingletons v0.1.2
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [cc61a311] + FLoops v0.2.2
#   [b9860ae5] + FLoopsBase v0.1.1
#   [076d061b] + HashArrayMappedTries v0.2.0
#   [22cec73e] + InitialValues v0.3.1
#   [b14d175d] + JuliaVariables v0.2.4
#   [63c18a36] + KernelAbstractions v0.9.37
#   [c2834f40] + MLCore v1.0.0
#   [f1d291b0] + MLUtils v0.4.8
#   [128add7d] + MicroCollections v0.2.0
#   [872c559c] + NNlib v0.9.30
#   [71a1bf82] + NameResolution v0.1.5
#   [8162dcfd] + PrettyPrint v0.2.0
#   [92933f4c] + ProgressMeter v1.10.4
#   [7e506255] + ScopedValues v1.3.0
#   [605ecd9f] + ShowCases v0.1.0
#   [171d559e] + SplittablesBase v0.1.15
#   [28d57a85] + Transducers v0.4.84
#   [013be700] + UnsafeAtomics v0.3.0
# Precompiling project...
#    3667.1 ms  ✓ PrettyPrint
#    3664.1 ms  ✓ ArgCheck
#    3654.6 ms  ✓ ShowCases
#    4248.4 ms  ✓ InitialValues
#    4837.9 ms  ✓ UnsafeAtomics
#    1166.2 ms  ✓ DefineSingletons
#    2105.6 ms  ✓ HashArrayMappedTries
#    2103.4 ms  ✓ DelimitedFiles
#    2849.1 ms  ✓ ProgressMeter
#    1724.4 ms  ✓ ContextVariablesX
#    3019.7 ms  ✓ Baselet
#    1412.7 ms  ✓ NameResolution
#    2856.1 ms  ✓ MLCore
#    2985.9 ms  ✓ SplittablesBase
#    2510.8 ms  ✓ BangBang
#    1374.8 ms  ✓ Atomix
#    1282.7 ms  ✓ ScopedValues
#    2070.8 ms  ✓ FLoopsBase
#    5121.9 ms  ✓ DataInterpolations
#    3214.9 ms  ✓ BangBang → BangBangStaticArraysExt
#    2653.9 ms  ✓ BangBang → BangBangChainRulesCoreExt
#    2239.5 ms  ✓ BangBang → BangBangTablesExt
#    2482.8 ms  ✓ MicroCollections
#    6336.1 ms  ✓ JuliaVariables
#    4748.6 ms  ✓ DataInterpolations → DataInterpolationsOptimExt
#    3683.7 ms  ✓ DataInterpolations → DataInterpolationsChainRulesCoreExt
#    8137.6 ms  ✓ KernelAbstractions
#    6344.2 ms  ✓ Transducers
#    9803.7 ms  ✓ DataInterpolations → DataInterpolationsSymbolicsExt
#    2962.2 ms  ✓ KernelAbstractions → LinearAlgebraExt
#    3864.2 ms  ✓ KernelAbstractions → EnzymeExt
#    3905.2 ms  ✓ KernelAbstractions → SparseArraysExt
#    3234.4 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsKernelAbstractionsExt
#    2599.1 ms  ✓ Transducers → TransducersAdaptExt
#    4323.8 ms  ✓ Transducers → TransducersBlockArraysExt
#    4312.4 ms  ✓ Transducers → TransducersLazyArraysExt
#    8292.6 ms  ✓ LinearSolve → LinearSolveKernelAbstractionsExt
#    7377.8 ms  ✓ FLoops
#    8540.5 ms  ✓ NNlib
#    3487.2 ms  ✓ NNlib → NNlibForwardDiffExt
#    3943.4 ms  ✓ NNlib → NNlibEnzymeCoreExt
#    3935.8 ms  ✓ NNlib → NNlibSpecialFunctionsExt
#    9607.5 ms  ✓ MLUtils
#   15237.4 ms  ✓ DataDrivenDiffEq
#   44 dependencies successfully precompiled in 64 seconds. 355 already precompiled.
#    Resolving package versions...
#    Installed ZygoteRules ───────── v0.2.7
#    Installed CEnum ─────────────── v0.5.0
#    Installed Tracy ─────────────── v0.1.5
#    Installed LibTracyClient_jll ── v0.9.1+6
#    Installed Enzyme_jll ────────── v0.0.184+0
#    Installed RealDot ───────────── v0.1.0
#    Installed FunctionProperties ── v0.1.2
#    Installed Optimisers ────────── v0.4.6
#    Installed SciMLSensitivity ──── v7.87.0
#    Installed LLVM ──────────────── v9.4.2
#    Installed IRTools ───────────── v0.4.15
#    Installed LLVMExtra_jll ─────── v0.0.37+2
#    Installed Scratch ───────────── v1.3.0
#    Installed Tracker ───────────── v0.2.38
#    Installed AbstractFFTs ──────── v1.5.0
#    Installed Zygote ────────────── v0.7.10
#    Installed ChainRules ────────── v1.72.5
#    Installed SparseInverseSubset ─ v0.1.2
#    Installed Enzyme ────────────── v0.13.57
#    Installed StructArrays ──────── v0.7.1
#    Installed GPUCompiler ───────── v1.6.1
#    Installed StructIO ──────────── v0.3.1
#    Installed ReverseDiff ───────── v1.16.1
#    Installed Cassette ──────────── v0.3.14
#    Installed ObjectFile ────────── v0.4.4
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [1ed8b502] + SciMLSensitivity v7.87.0
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [fa961155] + CEnum v0.5.0
#   [7057c7e9] + Cassette v0.3.14
#   [082447d4] + ChainRules v1.72.5
#   [7da242da] + Enzyme v0.13.57
#   [f62d2435] + FunctionProperties v0.1.2
#   [61eb1bfa] + GPUCompiler v1.6.1
#   [7869d1d1] + IRTools v0.4.15
#   [929cbde3] + LLVM v9.4.2
#   [d8793406] + ObjectFile v0.4.4
#   [3bd65402] + Optimisers v0.4.6
#   [c1ae055f] + RealDot v0.1.0
#   [37e2e3b7] + ReverseDiff v1.16.1
#   [1ed8b502] + SciMLSensitivity v7.87.0
#   [6c6a2e73] + Scratch v1.3.0
#   [dc90abb0] + SparseInverseSubset v0.1.2
#   [09ab397b] + StructArrays v0.7.1
#   [53d494c1] + StructIO v0.3.1
#   [9f7883ad] + Tracker v0.2.38
#   [e689c965] + Tracy v0.1.5
#   [e88e6eb3] + Zygote v0.7.10
#   [700de1a5] + ZygoteRules v0.2.7
#   [7cc45869] + Enzyme_jll v0.0.184+0
#   [dad2f222] + LLVMExtra_jll v0.0.37+2
#   [ad6e5548] + LibTracyClient_jll v0.9.1+6
# Precompiling project...
#    3196.4 ms  ✓ RealDot
#    3218.2 ms  ✓ CEnum
#    3209.7 ms  ✓ StructIO
#    3258.1 ms  ✓ AbstractFFTs
#    4143.6 ms  ✓ Cassette
#    1232.3 ms  ✓ Scratch
#    2325.9 ms  ✓ SparseInverseSubset
#    2290.8 ms  ✓ LibTracyClient_jll
#    2905.7 ms  ✓ StructArrays
#    1851.8 ms  ✓ ZygoteRules
#    3069.3 ms  ✓ IRTools
#    2975.2 ms  ✓ Optimisers
#    3755.5 ms  ✓ Enzyme_jll
#    4206.4 ms  ✓ LLVMExtra_jll
#    2428.9 ms  ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#    5101.0 ms  ✓ ObjectFile
#    1935.4 ms  ✓ FunctionProperties
#    1761.3 ms  ✓ StructArrays → StructArraysAdaptExt
#    2366.2 ms  ✓ Tracy
#    4573.6 ms  ✓ AbstractFFTs → AbstractFFTsTestExt
#    2334.6 ms  ✓ StructArrays → StructArraysSparseArraysExt
#    1625.2 ms  ✓ StructArrays → StructArraysLinearAlgebraExt
#    3067.3 ms  ✓ StructArrays → StructArraysStaticArraysExt
#    3831.6 ms  ✓ StructArrays → StructArraysGPUArraysCoreExt
#    2540.1 ms  ✓ Accessors → StructArraysExt
#    2148.4 ms  ✓ BangBang → BangBangStructArraysExt
#    4061.0 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsStructArraysExt
#    3172.5 ms  ✓ Optimisers → OptimisersEnzymeCoreExt
#    3161.0 ms  ✓ Optimisers → OptimisersAdaptExt
#   11080.9 ms  ✓ Tracker
#   14274.7 ms  ✓ LLVM
#   12003.7 ms  ✓ ChainRules
#    3777.3 ms  ✓ FastPower → FastPowerTrackerExt
#    3850.9 ms  ✓ DifferentiationInterface → DifferentiationInterfaceTrackerExt
#    4423.5 ms  ✓ ArrayInterface → ArrayInterfaceTrackerExt
#    5310.2 ms  ✓ Tracker → TrackerPDMatsExt
#    3943.5 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsTrackerExt
#   35714.6 ms  ✓ ReverseDiff
#    5372.7 ms  ✓ UnsafeAtomics → UnsafeAtomicsLLVM
#    7601.0 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveTrackerExt
#    7166.3 ms  ✓ DiffEqBase → DiffEqBaseTrackerExt
#    2897.5 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesExt
#    9023.0 ms  ✓ FastPower → FastPowerReverseDiffExt
#    9508.3 ms  ✓ DifferentiationInterface → DifferentiationInterfaceReverseDiffExt
#    9071.0 ms  ✓ ArrayInterface → ArrayInterfaceReverseDiffExt
#    9363.7 ms  ✓ PreallocationTools → PreallocationToolsReverseDiffExt
#   12951.3 ms  ✓ SymbolicUtils → SymbolicUtilsReverseDiffExt
#   13770.3 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveReverseDiffExt
#   11950.6 ms  ✓ DiffEqBase → DiffEqBaseReverseDiffExt
#   12596.0 ms  ✓ DiffEqNoiseProcess → DiffEqNoiseProcessReverseDiffExt
#   56367.0 ms  ✓ GPUCompiler
#   67099.8 ms  ✓ Zygote
#    4686.8 ms  ✓ DifferentiationInterface → DifferentiationInterfaceZygoteExt
#    5681.4 ms  ✓ Zygote → ZygoteTrackerExt
#    7711.5 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsZygoteExt
#    8897.1 ms  ✓ SciMLBase → SciMLBaseZygoteExt
#    9152.6 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsReverseDiffExt
#  118874.8 ms  ✓ Enzyme
#   10003.4 ms  ✓ Enzyme → EnzymeChainRulesCoreExt
#   11041.4 ms  ✓ Enzyme → EnzymeStaticArraysExt
#   11009.7 ms  ✓ Enzyme → EnzymeGPUArraysCoreExt
#   11023.8 ms  ✓ Enzyme → EnzymeLogExpFunctionsExt
#   11190.0 ms  ✓ Enzyme → EnzymeSpecialFunctionsExt
#    5395.9 ms  ✓ FastPower → FastPowerEnzymeExt
#    5983.5 ms  ✓ QuadGK → QuadGKEnzymeExt
#    6159.1 ms  ✓ DifferentiationInterface → DifferentiationInterfaceEnzymeExt
#    7613.2 ms  ✓ DiffEqBase → DiffEqBaseEnzymeExt
#   14373.4 ms  ✓ SciMLSensitivity
#   68 dependencies successfully precompiled in 249 seconds. 399 already precompiled.
#    Resolving package versions...
#    Installed DataDrivenSparse ─ v0.1.3
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [5b588203] + DataDrivenSparse v0.1.3
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [5b588203] + DataDrivenSparse v0.1.3
# Precompiling project...
#   13308.5 ms  ✓ DataDrivenSparse
#   1 dependency successfully precompiled in 20 seconds. 467 already precompiled.
#    Resolving package versions...
#    Installed LBFGSB ───────────────────── v0.4.1
#    Installed ProgressLogging ──────────── v0.1.5
#    Installed LeftChildRightSiblingTrees ─ v0.2.0
#    Installed LoggingExtras ────────────── v1.1.0
#    Installed TerminalLoggers ──────────── v0.1.7
#    Installed L_BFGS_B_jll ─────────────── v3.0.1+0
#    Installed ConsoleProgressMonitor ───── v0.1.2
#    Installed SparseConnectivityTracer ─── v0.6.21
#    Installed OptimizationBase ─────────── v2.8.0
#    Installed Optimization ─────────────── v4.4.0
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [7f7a1694] + Optimization v4.4.0
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [88cd18e8] + ConsoleProgressMonitor v0.1.2
#   [5be7bae1] + LBFGSB v0.4.1
#   [1d6d02ad] + LeftChildRightSiblingTrees v0.2.0
#   [e6f89c97] + LoggingExtras v1.1.0
#   [7f7a1694] + Optimization v4.4.0
#   [bca83a33] + OptimizationBase v2.8.0
#   [33c8b6b6] + ProgressLogging v0.1.5
#   [9f842d2f] + SparseConnectivityTracer v0.6.21
#   [5d786b92] + TerminalLoggers v0.1.7
#   [81d17ec3] + L_BFGS_B_jll v3.0.1+0
# Precompiling project...
#    3818.5 ms  ✓ ProgressLogging
#    3956.9 ms  ✓ LeftChildRightSiblingTrees
#    3931.7 ms  ✓ ConsoleProgressMonitor
#    3964.0 ms  ✓ LoggingExtras
#    1933.4 ms  ✓ L_BFGS_B_jll
#    2722.0 ms  ✓ TerminalLoggers
#    7685.4 ms  ✓ SparseConnectivityTracer
#    1365.0 ms  ✓ LBFGSB
#    2311.2 ms  ✓ SparseConnectivityTracer → SparseConnectivityTracerLogExpFunctionsExt
#    2623.9 ms  ✓ SparseConnectivityTracer → SparseConnectivityTracerNaNMathExt
#    4045.9 ms  ✓ SparseConnectivityTracer → SparseConnectivityTracerDataInterpolationsExt
#    4047.6 ms  ✓ SparseConnectivityTracer → SparseConnectivityTracerSpecialFunctionsExt
#    2263.4 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseConnectivityTracerExt
#    5155.7 ms  ✓ SparseConnectivityTracer → SparseConnectivityTracerNNlibExt
#    2561.9 ms  ✓ PreallocationTools → PreallocationToolsSparseConnectivityTracerExt
#    3817.4 ms  ✓ OptimizationBase
#    1879.7 ms  ✓ OptimizationBase → OptimizationForwardDiffExt
#    7440.5 ms  ✓ OptimizationBase → OptimizationZygoteExt
#    7413.4 ms  ✓ OptimizationBase → OptimizationMLUtilsExt
#    1560.3 ms  ✓ OptimizationBase → OptimizationFiniteDiffExt
#    9570.9 ms  ✓ OptimizationBase → OptimizationReverseDiffExt
#    8825.0 ms  ✓ OptimizationBase → OptimizationEnzymeExt
#    5319.1 ms  ✓ Optimization
#   18365.2 ms  ✓ OptimizationBase → OptimizationMTKExt
#   24 dependencies successfully precompiled in 36 seconds. 468 already precompiled.
#    Resolving package versions...
#    Installed OptimizationOptimisers ─ v0.3.7
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [42dfb2eb] + OptimizationOptimisers v0.3.7
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [42dfb2eb] + OptimizationOptimisers v0.3.7
# Precompiling project...
#    3779.5 ms  ✓ OptimizationOptimisers
#   1 dependency successfully precompiled in 8 seconds. 492 already precompiled.
#    Resolving package versions...
#    Installed OptimizationOptimJL ─ v0.4.3
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [36348300] + OptimizationOptimJL v0.4.3
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [36348300] + OptimizationOptimJL v0.4.3
# Precompiling project...
#   22429.5 ms  ✓ OptimizationOptimJL
#   1 dependency successfully precompiled in 26 seconds. 493 already precompiled.
#    Resolving package versions...
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [d3d80556] + LineSearches v7.4.0
#   No Changes to `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`

# %%
# SciML Tools
using OrdinaryDiffEq, ModelingToolkit, DataDrivenDiffEq, SciMLSensitivity, DataDrivenSparse
using Optimization, OptimizationOptimisers, OptimizationOptimJL, LineSearches

# %%
# Standard Libraries
using LinearAlgebra, Statistics

# %%
Pkg.add("ComponentArrays")
# Out:
#    Resolving package versions...
#    Installed ComponentArrays ─ v0.15.28
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [b0b7db55] + ComponentArrays v0.15.28
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [b0b7db55] + ComponentArrays v0.15.28
# Precompiling project...
#    5948.4 ms  ✓ ComponentArrays
#    3977.6 ms  ✓ ComponentArrays → ComponentArraysOptimisersExt
#    5519.8 ms  ✓ ComponentArrays → ComponentArraysRecursiveArrayToolsExt
#    5635.8 ms  ✓ ComponentArrays → ComponentArraysTrackerExt
#    5968.4 ms  ✓ ComponentArrays → ComponentArraysZygoteExt
#    4283.1 ms  ✓ ComponentArrays → ComponentArraysKernelAbstractionsExt
#    4261.1 ms  ✓ ComponentArrays → ComponentArraysSciMLBaseExt
#    9522.0 ms  ✓ ComponentArrays → ComponentArraysReverseDiffExt
#   8 dependencies successfully precompiled in 23 seconds. 494 already precompiled.

# %%
Pkg.add("Lux")
# Out:
#    Resolving package versions...
#    Installed MLDataDevices ────── v1.11.0
#    Installed WeightInitializers ─ v1.1.3
#    Installed LuxCore ──────────── v1.2.6
#    Installed LuxLib ───────────── v1.9.0
#    Installed Lux ──────────────── v1.15.0
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [b2108857] + Lux v1.15.0
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [b2108857] + Lux v1.15.0
#   [bb33d45b] + LuxCore v1.2.6
#   [82251201] + LuxLib v1.9.0
#   [7e8f7934] + MLDataDevices v1.11.0
#   [d49dbf32] + WeightInitializers v1.1.3
# Precompiling project...
#    2425.1 ms  ✓ MLDataDevices
#    3243.7 ms  ✓ LuxCore
#    1872.6 ms  ✓ MLDataDevices → MLDataDevicesComponentArraysExt
#    3066.0 ms  ✓ MLDataDevices → MLDataDevicesChainRulesCoreExt
#    2037.5 ms  ✓ MLDataDevices → MLDataDevicesFillArraysExt
#    5987.3 ms  ✓ MLDataDevices → MLDataDevicesTrackerExt
#    8164.9 ms  ✓ WeightInitializers
#    4731.0 ms  ✓ MLDataDevices → MLDataDevicesZygoteExt
#    2649.0 ms  ✓ MLDataDevices → MLDataDevicesSparseArraysExt
#    3105.8 ms  ✓ MLDataDevices → MLDataDevicesChainRulesExt
#    3685.9 ms  ✓ MLDataDevices → MLDataDevicesRecursiveArrayToolsExt
#    4709.6 ms  ✓ MLDataDevices → MLDataDevicesMLUtilsExt
#    2689.6 ms  ✓ LuxCore → LuxCoreChainRulesCoreExt
#    6392.1 ms  ✓ MLDataDevices → MLDataDevicesReverseDiffExt
#    4393.5 ms  ✓ OptimizationBase → OptimizationMLDataDevicesExt
#    2679.9 ms  ✓ LuxCore → LuxCoreFunctorsExt
#    4293.6 ms  ✓ LuxCore → LuxCoreArrayInterfaceTrackerExt
#    3422.5 ms  ✓ LuxCore → LuxCoreEnzymeCoreExt
#    2891.9 ms  ✓ LuxCore → LuxCoreSetfieldExt
#    6703.2 ms  ✓ LuxCore → LuxCoreArrayInterfaceReverseDiffExt
#    1103.4 ms  ✓ LuxCore → LuxCoreMLDataDevicesExt
#    1741.9 ms  ✓ WeightInitializers → WeightInitializersChainRulesCoreExt
#    5957.6 ms  ✓ LuxLib
#    3809.3 ms  ✓ LuxLib → LuxLibEnzymeExt
#    6752.4 ms  ✓ LuxLib → LuxLibTrackerExt
#    7594.1 ms  ✓ LuxLib → LuxLibReverseDiffExt
#   12546.0 ms  ✓ Lux
#   24636.0 ms  ✓ Lux → LuxMLUtilsExt
#   24649.5 ms  ✓ Lux → LuxTrackerExt
#   24687.1 ms  ✓ Lux → LuxZygoteExt
#   24676.5 ms  ✓ Lux → LuxEnzymeExt
#   24668.4 ms  ✓ Lux → LuxReverseDiffExt
#    2978.8 ms  ✓ Lux → LuxComponentArraysExt
#    7663.6 ms  ✓ Symbolics → SymbolicsLuxExt
#   34 dependencies successfully precompiled in 75 seconds. 502 already precompiled.

# %%
Pkg.add("Zygote")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [e88e6eb3] + Zygote v0.7.10
#   No Changes to `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`

# %%
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#    Installed x265_jll ───────────────────── v3.5.0+0
#    Installed JpegTurbo_jll ──────────────── v3.1.1+0
#    Installed Libmount_jll ───────────────── v2.41.0+0
#    Installed GR_jll ─────────────────────── v0.73.17+0
#    Installed libfdk_aac_jll ─────────────── v2.0.4+0
#    Installed LERC_jll ───────────────────── v4.0.1+0
#    Installed Opus_jll ───────────────────── v1.5.2+0
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed Contour ────────────────────── v0.6.3
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Measures ───────────────────── v0.3.2
#    Installed ConcurrentUtilities ────────── v2.5.0
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.2+0
#    Installed Xorg_xcb_util_image_jll ────── v0.4.1+0
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed OpenSSL ────────────────────── v1.5.0
#    Installed Xorg_libSM_jll ─────────────── v1.2.6+0
#    Installed PlotUtils ──────────────────── v1.4.3
#    Installed HTTP ───────────────────────── v1.10.17
#    Installed ColorSchemes ───────────────── v3.30.0
#    Installed Xorg_xcb_util_jll ──────────── v0.4.1+0
#    Installed Xorg_libXinerama_jll ───────── v1.1.6+0
#    Installed Fontconfig_jll ─────────────── v2.16.0+0
#    Installed Xorg_libxkbfile_jll ────────── v1.1.3+0
#    Installed Xorg_libXau_jll ────────────── v1.0.13+0
#    Installed Cairo_jll ──────────────────── v1.18.5+0
#    Installed EpollShim_jll ──────────────── v0.0.20230411+1
#    Installed GR ─────────────────────────── v0.73.17
#    Installed Bzip2_jll ──────────────────── v1.0.9+0
#    Installed xkbcommon_jll ──────────────── v1.9.2+0
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.1+0
#    Installed FFMPEG ─────────────────────── v0.4.2
#    Installed Pango_jll ──────────────────── v1.56.3+0
#    Installed XZ_jll ─────────────────────── v5.8.1+0
#    Installed SimpleBufferStream ─────────── v1.2.0
#    Installed Showoff ────────────────────── v1.0.3
#    Installed PlotThemes ─────────────────── v3.3.0
#    Installed FriBidi_jll ────────────────── v1.0.17+0
#    Installed fzf_jll ────────────────────── v0.61.1+0
#    Installed HarfBuzz_jll ───────────────── v8.5.1+0
#    Installed LZO_jll ────────────────────── v2.10.3+0
#    Installed GLFW_jll ───────────────────── v3.4.0+2
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed TranscodingStreams ─────────── v0.11.3
#    Installed x264_jll ───────────────────── v2021.5.5+0
#    Installed FreeType2_jll ──────────────── v2.13.4+0
#    Installed ExceptionUnwrapping ────────── v0.1.11
#    Installed libpng_jll ─────────────────── v1.6.50+0
#    Installed libaom_jll ─────────────────── v3.11.0+0
#    Installed Xorg_libxcb_jll ────────────── v1.17.1+0
#    Installed Colors ─────────────────────── v0.13.1
#    Installed JLFzf ──────────────────────── v0.1.11
#    Installed CodecZlib ──────────────────── v0.7.8
#    Installed mtdev_jll ──────────────────── v1.1.7+0
#    Installed ColorTypes ─────────────────── v0.12.1
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.5+0
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed eudev_jll ──────────────────── v3.2.14+0
#    Installed Expat_jll ──────────────────── v2.6.5+0
#    Installed Xorg_libXext_jll ───────────── v1.3.7+0
#    Installed Dbus_jll ───────────────────── v1.16.2+0
#    Installed Zstd_jll ───────────────────── v1.5.7+1
#    Installed ColorVectorSpace ───────────── v0.11.0
#    Installed Libtiff_jll ────────────────── v4.7.1+0
#    Installed Libffi_jll ─────────────────── v3.4.7+0
#    Installed Plots ──────────────────────── v1.40.16
#    Installed libevdev_jll ───────────────── v1.13.4+0
#    Installed Xorg_libXrender_jll ────────── v0.9.12+0
#    Installed libinput_jll ───────────────── v1.28.1+0
#    Installed Ogg_jll ────────────────────── v1.3.6+0
#    Installed Xorg_libXi_jll ─────────────── v1.8.3+0
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed Qt6ShaderTools_jll ─────────── v6.8.2+1
#    Installed Qt6Declarative_jll ─────────── v6.8.2+1
#    Installed Libuuid_jll ────────────────── v2.41.0+0
#    Installed Xorg_libXcursor_jll ────────── v1.2.4+0
#    Installed StableRNGs ─────────────────── v1.0.3
#    Installed Xorg_libICE_jll ────────────── v1.1.2+0
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.10+0
#    Installed libass_jll ─────────────────── v0.15.2+0
#    Installed Graphite2_jll ──────────────── v1.3.15+0
#    Installed Pixman_jll ─────────────────── v0.44.2+0
#    Installed Wayland_jll ────────────────── v1.24.0+0
#    Installed Xorg_xtrans_jll ────────────── v1.6.0+0
#    Installed OpenSSL_jll ────────────────── v3.5.1+0
#    Installed FFMPEG_jll ─────────────────── v4.4.4+1
#    Installed Xorg_xkeyboard_config_jll ──── v2.44.0+0
#    Installed BitFlags ───────────────────── v0.1.9
#    Installed LAME_jll ───────────────────── v3.100.3+0
#    Installed LLVMOpenMP_jll ─────────────── v18.1.8+0
#    Installed GettextRuntime_jll ─────────── v0.22.4+0
#    Installed Xorg_libXfixes_jll ─────────── v6.0.1+0
#    Installed Qt6Wayland_jll ─────────────── v6.8.2+1
#    Installed Xorg_libXrandr_jll ─────────── v1.5.5+0
#    Installed FixedPointNumbers ──────────── v0.8.5
#    Installed Libiconv_jll ───────────────── v1.18.0+0
#    Installed Qt6Base_jll ────────────────── v6.8.2+1
#    Installed Glib_jll ───────────────────── v2.84.3+0
#    Installed Libglvnd_jll ───────────────── v1.7.1+1
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed libvorbis_jll ──────────────── v1.3.8+0
#    Installed Xorg_libXdmcp_jll ──────────── v1.1.6+0
#    Installed Xorg_libX11_jll ────────────── v1.8.12+0
#    Installed UnitfulLatexify ────────────── v1.7.0
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [91a5bcdd] + Plots v1.40.16
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`
#   [d1d4a3ce] + BitFlags v0.1.9
#   [944b1d66] + CodecZlib v0.7.8
#   [35d6a980] + ColorSchemes v3.30.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.1
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [d38c429a] + Contour v0.6.3
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.2
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [28b8d3ca] + GR v0.73.17
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.17
#   [1019f520] + JLFzf v0.1.11
#   [442fdcdd] + Measures v0.3.2
#   [4d8831e6] + OpenSSL v1.5.0
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.3
#   [91a5bcdd] + Plots v1.40.16
#   [01d81517] + RecipesPipeline v0.6.12
#   [05181044] + RelocatableFolders v1.0.1
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [860ef19b] + StableRNGs v1.0.3
#   [62fd8b95] + TensorCore v0.1.1
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [1cfade01] + UnicodeFun v0.4.1
#   [45397f5d] + UnitfulLatexify v1.7.0
#   [41fe7b60] + Unzip v0.2.0
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [83423d85] + Cairo_jll v1.18.5+0
#   [ee1fde0b] + Dbus_jll v1.16.2+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.6.5+0
# ⌅ [b22a6f82] + FFMPEG_jll v4.4.4+1
#   [a3f928ae] + Fontconfig_jll v2.16.0+0
#   [d7e528f0] + FreeType2_jll v2.13.4+0
#   [559328eb] + FriBidi_jll v1.0.17+0
#   [0656b61e] + GLFW_jll v3.4.0+2
#   [d2c73de3] + GR_jll v0.73.17+0
#   [b0724c58] + GettextRuntime_jll v0.22.4+0
#   [7746bdde] + Glib_jll v2.84.3+0
#   [3b182d85] + Graphite2_jll v1.3.15+0
#   [2e76f6c2] + HarfBuzz_jll v8.5.1+0
#   [aacddb02] + JpegTurbo_jll v3.1.1+0
#   [c1c5ebd0] + LAME_jll v3.100.3+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.8+0
#   [dd4b983a] + LZO_jll v2.10.3+0
#   [e9f186c6] + Libffi_jll v3.4.7+0
#   [7e76a0d4] + Libglvnd_jll v1.7.1+1
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [4b2f31a3] + Libmount_jll v2.41.0+0
#   [89763e89] + Libtiff_jll v4.7.1+0
#   [38a345b3] + Libuuid_jll v2.41.0+0
#   [e7412a2a] + Ogg_jll v1.3.6+0
#   [458c3c95] + OpenSSL_jll v3.5.1+0
#   [91d4177d] + Opus_jll v1.5.2+0
#   [36c8627f] + Pango_jll v1.56.3+0
# ⌅ [30392449] + Pixman_jll v0.44.2+0
#   [c0090381] + Qt6Base_jll v6.8.2+1
#   [629bc702] + Qt6Declarative_jll v6.8.2+1
#   [ce943373] + Qt6ShaderTools_jll v6.8.2+1
#   [e99dba38] + Qt6Wayland_jll v6.8.2+1
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.24.0+0
#   [ffd25f8a] + XZ_jll v5.8.1+0
#   [f67eecfb] + Xorg_libICE_jll v1.1.2+0
#   [c834827a] + Xorg_libSM_jll v1.2.6+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.12+0
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.13+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.4+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.6+0
#   [1082639a] + Xorg_libXext_jll v1.3.7+0
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.1+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.3+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.6+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.5+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.12+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.1+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.3+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.5+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.1+0
#   [2def613f] + Xorg_xcb_util_jll v0.4.1+0
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.1+0
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.10+0
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.2+0
#   [35661453] + Xorg_xkbcomp_jll v1.4.7+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.44.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.6.0+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [35ca27e7] + eudev_jll v3.2.14+0
#   [214eeab7] + fzf_jll v0.61.1+0
#   [a4ae2306] + libaom_jll v3.11.0+0
# ⌅ [0ac62f75] + libass_jll v0.15.2+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.13.4+0
#   [f638f0a6] + libfdk_aac_jll v2.0.4+0
#   [36db933b] + libinput_jll v1.28.1+0
#   [b53b4c65] + libpng_jll v1.6.50+0
#   [f27f6e37] + libvorbis_jll v1.3.8+0
#   [009596ad] + mtdev_jll v1.1.7+0
# ⌅ [1270edf5] + x264_jll v2021.5.5+0
# ⌅ [dfaa095f] + x265_jll v3.5.0+0
#   [d8fb68d0] + xkbcommon_jll v1.9.2+0
#   [efcefdf7] + PCRE2_jll v10.42.0+1
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#    5916.9 ms  ✓ Contour
#    5020.3 ms  ✓ Measures
#    4961.9 ms  ✓ SimpleBufferStream
#    7192.3 ms  ✓ TranscodingStreams
#    7280.2 ms  ✓ Grisu
#    1339.1 ms  ✓ BitFlags
#    1588.1 ms  ✓ StableRNGs
#    1664.0 ms  ✓ TensorCore
#    1800.5 ms  ✓ Unzip
#    1374.6 ms  ✓ RelocatableFolders
#    3131.1 ms  ✓ ConcurrentUtilities
#    2766.9 ms  ✓ ExceptionUnwrapping
#    2201.9 ms  ✓ Xorg_libICE_jll
#    7025.2 ms  ✓ FixedPointNumbers
#    2732.5 ms  ✓ OpenSSL_jll
#    5967.1 ms  ✓ UnicodeFun
#    5058.0 ms  ✓ UnitfulLatexify
#    1835.3 ms  ✓ Libffi_jll
#    1554.4 ms  ✓ Libuuid_jll
#    2045.7 ms  ✓ LLVMOpenMP_jll
#    2252.8 ms  ✓ fzf_jll
#    2709.9 ms  ✓ JpegTurbo_jll
#    2188.5 ms  ✓ mtdev_jll
#    2428.8 ms  ✓ Ogg_jll
#    2396.1 ms  ✓ x265_jll
#    1937.5 ms  ✓ x264_jll
#    2002.3 ms  ✓ Libiconv_jll
#    1994.7 ms  ✓ FriBidi_jll
#    2005.7 ms  ✓ Graphite2_jll
#    1637.6 ms  ✓ EpollShim_jll
#    1597.3 ms  ✓ Xorg_libXau_jll
#    1942.6 ms  ✓ Xorg_libXdmcp_jll
#    2159.1 ms  ✓ libpng_jll
#    2096.5 ms  ✓ LAME_jll
#    2058.4 ms  ✓ libaom_jll
#    1951.6 ms  ✓ Zstd_jll
#    1856.6 ms  ✓ LZO_jll
#    1883.7 ms  ✓ Expat_jll
#    1854.1 ms  ✓ Opus_jll
#    1662.4 ms  ✓ Xorg_xtrans_jll
#    1468.5 ms  ✓ eudev_jll
#    1692.0 ms  ✓ Libmount_jll
#    1812.5 ms  ✓ Bzip2_jll
#    2125.3 ms  ✓ libfdk_aac_jll
#    1994.6 ms  ✓ LERC_jll
#    2193.1 ms  ✓ XZ_jll
#    1592.5 ms  ✓ libevdev_jll
#    1525.7 ms  ✓ Showoff
#    1863.3 ms  ✓ CodecZlib
#    1675.7 ms  ✓ Xorg_libSM_jll
#    1948.3 ms  ✓ Pixman_jll
#    2558.7 ms  ✓ libvorbis_jll
#    4678.2 ms  ✓ ColorTypes
#    3707.6 ms  ✓ JLFzf
#    2661.3 ms  ✓ GettextRuntime_jll
#    1930.8 ms  ✓ Xorg_libxcb_jll
#    5372.8 ms  ✓ OpenSSL
#    1796.6 ms  ✓ Dbus_jll
#    1757.5 ms  ✓ Wayland_jll
#    1479.1 ms  ✓ libinput_jll
#    2104.6 ms  ✓ FreeType2_jll
#    2296.6 ms  ✓ ColorTypes → StyledStringsExt
#    3522.5 ms  ✓ Libtiff_jll
#    2531.5 ms  ✓ Xorg_xcb_util_jll
#    2593.7 ms  ✓ Xorg_libX11_jll
#    4508.7 ms  ✓ Glib_jll
#    7160.0 ms  ✓ ColorVectorSpace
#    2079.5 ms  ✓ Xorg_xcb_util_keysyms_jll
#    1630.4 ms  ✓ Xorg_xcb_util_renderutil_jll
#    4127.5 ms  ✓ Fontconfig_jll
#    1622.4 ms  ✓ Xorg_xcb_util_image_jll
#    1742.5 ms  ✓ Xorg_xcb_util_wm_jll
#    1684.3 ms  ✓ Xorg_libXrender_jll
#    1788.7 ms  ✓ Xorg_libXext_jll
#    2263.7 ms  ✓ Xorg_libXfixes_jll
#    1951.2 ms  ✓ Xorg_libxkbfile_jll
#    2569.7 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#    1741.0 ms  ✓ Xorg_xcb_util_cursor_jll
#    1689.7 ms  ✓ Xorg_libXinerama_jll
#    1680.6 ms  ✓ Xorg_libXrandr_jll
#    1664.2 ms  ✓ Libglvnd_jll
#   15647.3 ms  ✓ Colors
#    1605.6 ms  ✓ Xorg_libXcursor_jll
#    1830.4 ms  ✓ Xorg_libXi_jll
#    1846.8 ms  ✓ Xorg_xkbcomp_jll
#    3830.2 ms  ✓ Cairo_jll
#    2313.8 ms  ✓ Xorg_xkeyboard_config_jll
#    4604.1 ms  ✓ SparseMatrixColorings → SparseMatrixColoringsColorsExt
#    2321.8 ms  ✓ xkbcommon_jll
#    7021.9 ms  ✓ Zygote → ZygoteColorsExt
#    2200.9 ms  ✓ Vulkan_Loader_jll
#    6328.0 ms  ✓ HarfBuzz_jll
#   12046.0 ms  ✓ ColorSchemes
#    4330.6 ms  ✓ libass_jll
#    4796.5 ms  ✓ Pango_jll
#    7057.8 ms  ✓ Qt6Base_jll
#    1842.7 ms  ✓ libdecor_jll
#    2569.1 ms  ✓ GLFW_jll
#    3225.8 ms  ✓ Qt6ShaderTools_jll
#    8811.7 ms  ✓ FFMPEG_jll
#    3581.5 ms  ✓ FFMPEG
#    5637.4 ms  ✓ GR_jll
#   10423.4 ms  ✓ Qt6Declarative_jll
#    1127.1 ms  ✓ Qt6Wayland_jll
#   32089.4 ms  ✓ PlotUtils
#   58256.1 ms  ✓ HTTP
#    8634.4 ms  ✓ PlotThemes
#   11858.0 ms  ✓ RecipesPipeline
#   12274.4 ms  ✓ GR
#  102089.0 ms  ✓ Plots
#    7537.4 ms  ✓ Plots → UnitfulExt
#    8448.5 ms  ✓ Plots → IJuliaExt
#   112 dependencies successfully precompiled in 248 seconds. 537 already precompiled.

# %%
Pkg.add("StableRNGs")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\lenovo\.julia\environments\v1.11\Project.toml`
#   [860ef19b] + StableRNGs v1.0.3
#   No Changes to `C:\Users\lenovo\.julia\environments\v1.11\Manifest.toml`

# %%
# External Libraries
using ComponentArrays, Lux, Zygote, Plots, StableRNGs
gr()
# Out:
# Plots.GRBackend()
